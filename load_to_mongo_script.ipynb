# %%
import requests
from config import key
import pymongo

# %%
# Create connection variable
conn = 'mongodb://localhost:27017'

# Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)

# Connect to a database. Will create one if not already available.
db = client.congress_db

# %%
votes_url = "https://api.propublica.org/congress/v1/house/votes/recent.json"
votes_r = requests.get(votes_url, headers={"X-API-Key": key})

# %%
votes_json = votes_r.json()
votes_json
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 Pro Publica Inc. All Rights Reserved.',
#  'results': {'chamber': 'House',
#   'offset': 0,
#   'num_results': 20,
#   'votes': [{'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 115,
#     'source': 'http://clerk.house.gov/evs/2020/roll115.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll115.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/115.json',
#     'bill': {'bill_id': 'hr6172-116',
#      'number': 'H.R.6172',
#      'sponsor_id': 'N000002',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6172.json',
#      'title': 'To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#      'latest_action': 'The Speaker appointed conferees: Nadler, Schiff, Lofgren, Jordan, and Nunes.'},
#     'amendment': {},
#     'question': 'On Motion to Disagree to the Senate Amendments and Request a Conference',
#     'question_text': '',
#     'description': 'USA FREEDOM Reauthorization Act',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-28',
#     'time': '15:10:00',
#     'result': 'Passed',
#     'democratic': {'yes': 211,
#      'no': 21,
#      'present': 0,
#      'not_voting': 1,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 73,
#      'no': 100,
#      'present': 0,
#      'not_voting': 24,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 284, 'no': 122, 'present': 0, 'not_voting': 25}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 114,
#     'source': 'http://clerk.house.gov/evs/2020/roll114.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll114.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/114.json',
#     'bill': {'bill_id': 'hr7010-116',
#      'number': 'H.R.7010',
#      'sponsor_id': 'P000616',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr7010.json',
#      'title': 'To amend the Small Business Act and the CARES Act to modify certain provisions related to the forgiveness of loans under the paycheck protection program, to allow recipients of loan forgiveness under the paycheck protection program to defer payroll taxes, and for other purposes.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#     'question_text': '',
#     'description': 'Paycheck Protection Program Flexibility Act',
#     'vote_type': '2/3 YEA-AND-NAY',
#     'date': '2020-05-28',
#     'time': '13:12:00',
#     'result': 'Passed',
#     'democratic': {'yes': 233,
#      'no': 0,
#      'present': 0,
#      'not_voting': 0,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 183,
#      'no': 1,
#      'present': 0,
#      'not_voting': 13,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 417, 'no': 1, 'present': 0, 'not_voting': 13}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 113,
#     'source': 'http://clerk.house.gov/evs/2020/roll113.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll113.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/113.json',
#     'bill': {'bill_id': 'hr6782-116',
#      'number': 'H.R.6782',
#      'sponsor_id': 'P000616',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6782.json',
#      'title': 'To require the Administrator of the Small Business Administration to submit a report on recipients of assistance under the paycheck protection program and the economic injury disaster loan program, and for other purposes.',
#      'latest_action': 'On motion to suspend the rules and pass the bill, as amended Failed by the Yeas and Nays: (2/3 required): 269 - 147 (Roll no. 113).'},
#     'amendment': {},
#     'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#     'question_text': '',
#     'description': 'TRUTH Act',
#     'vote_type': '2/3 YEA-AND-NAY',
#     'date': '2020-05-28',
#     'time': '11:59:00',
#     'result': 'Failed',
#     'democratic': {'yes': 231,
#      'no': 0,
#      'present': 0,
#      'not_voting': 2,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 38,
#      'no': 146,
#      'present': 0,
#      'not_voting': 13,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 269, 'no': 147, 'present': 0, 'not_voting': 15}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 112,
#     'source': 'http://clerk.house.gov/evs/2020/roll112.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll112.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/112.json',
#     'bill': {'bill_id': 'hres981-116',
#      'number': 'H.RES.981',
#      'sponsor_id': 'M000312',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres981.json',
#      'title': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Agreeing to the Resolution',
#     'question_text': '',
#     'description': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-27',
#     'time': '20:05:00',
#     'result': 'Passed',
#     'democratic': {'yes': 228,
#      'no': 5,
#      'present': 0,
#      'not_voting': 0,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 0,
#      'no': 183,
#      'present': 0,
#      'not_voting': 14,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 228, 'no': 189, 'present': 0, 'not_voting': 14}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 111,
#     'source': 'http://clerk.house.gov/evs/2020/roll111.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll111.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/111.json',
#     'bill': {'bill_id': 'hres981-116',
#      'number': 'H.RES.981',
#      'sponsor_id': 'M000312',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres981.json',
#      'title': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Ordering the Previous Question',
#     'question_text': '',
#     'description': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-27',
#     'time': '18:57:00',
#     'result': 'Passed',
#     'democratic': {'yes': 232,
#      'no': 0,
#      'present': 0,
#      'not_voting': 1,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 0,
#      'no': 181,
#      'present': 0,
#      'not_voting': 16,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 232, 'no': 182, 'present': 0, 'not_voting': 17}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 110,
#     'source': 'http://clerk.house.gov/evs/2020/roll110.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll110.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/110.json',
#     'bill': {'bill_id': 's3744-116',
#      'number': 'S.3744',
#      'sponsor_id': 'R000595',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/s3744.json',
#      'title': 'A bill to condemn gross human rights violations of ethnic Turkic Muslims in Xinjiang, and calling for an end to arbitrary detention, torture, and harassment of these communities inside and outside China.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Motion to Suspend the Rules and Pass',
#     'question_text': '',
#     'description': 'Uyghur Human Rights Policy Act',
#     'vote_type': '2/3 YEA-AND-NAY',
#     'date': '2020-05-27',
#     'time': '17:44:00',
#     'result': 'Passed',
#     'democratic': {'yes': 231,
#      'no': 0,
#      'present': 0,
#      'not_voting': 2,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 181,
#      'no': 1,
#      'present': 0,
#      'not_voting': 15,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 413, 'no': 1, 'present': 0, 'not_voting': 17}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 109,
#     'source': 'http://clerk.house.gov/evs/2020/roll109.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll109.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/109.json',
#     'bill': {'bill_id': 'hr6800-116',
#      'number': 'H.R.6800',
#      'sponsor_id': 'L000480',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6800.json',
#      'title': 'Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.',
#      'latest_action': 'Read the first time. Placed on Senate Legislative Calendar under Read the First Time.'},
#     'amendment': {},
#     'question': 'On Passage',
#     'question_text': '',
#     'description': 'HEROES Act',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-15',
#     'time': '21:24:00',
#     'result': 'Passed',
#     'democratic': {'yes': 207,
#      'no': 14,
#      'present': 0,
#      'not_voting': 12,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 1,
#      'no': 184,
#      'present': 0,
#      'not_voting': 11,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 208, 'no': 199, 'present': 0, 'not_voting': 23}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 108,
#     'source': 'http://clerk.house.gov/evs/2020/roll108.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll108.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/108.json',
#     'bill': {'bill_id': 'hr6800-116',
#      'number': 'H.R.6800',
#      'sponsor_id': 'L000480',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6800.json',
#      'title': 'Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.',
#      'latest_action': 'Read the first time. Placed on Senate Legislative Calendar under Read the First Time.'},
#     'amendment': {},
#     'question': 'On Motion to Recommit with Instructions',
#     'question_text': '',
#     'description': 'HEROES Act',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-15',
#     'time': '20:22:00',
#     'result': 'Failed',
#     'democratic': {'yes': 13,
#      'no': 208,
#      'present': 0,
#      'not_voting': 12,
#      'majority_position': 'No'},
#     'republican': {'yes': 185,
#      'no': 0,
#      'present': 0,
#      'not_voting': 11,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 198, 'no': 209, 'present': 0, 'not_voting': 23}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 107,
#     'source': 'http://clerk.house.gov/evs/2020/roll107.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll107.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/107.json',
#     'bill': {'bill_id': 'hres965-116',
#      'number': 'H.RES.965',
#      'sponsor_id': 'M000312',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres965.json',
#      'title': 'Authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Agreeing to the Resolution',
#     'question_text': '',
#     'description': 'Authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-15',
#     'time': '19:15:00',
#     'result': 'Passed',
#     'democratic': {'yes': 217,
#      'no': 3,
#      'present': 0,
#      'not_voting': 13,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 0,
#      'no': 185,
#      'present': 0,
#      'not_voting': 11,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 217, 'no': 189, 'present': 0, 'not_voting': 24}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 106,
#     'source': 'http://clerk.house.gov/evs/2020/roll106.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll106.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/106.json',
#     'bill': {'bill_id': 'hres967-116',
#      'number': 'H.RES.967',
#      'sponsor_id': 'M000312',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres967.json',
#      'title': 'Providing for consideration of the resolution (H. Res. 965) authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Agreeing to the Resolution',
#     'question_text': '',
#     'description': 'Providing for consideration of H. Res. 965; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-15',
#     'time': '12:28:00',
#     'result': 'Passed',
#     'democratic': {'yes': 207,
#      'no': 14,
#      'present': 0,
#      'not_voting': 12,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 0,
#      'no': 184,
#      'present': 0,
#      'not_voting': 12,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 207, 'no': 199, 'present': 0, 'not_voting': 24}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 105,
#     'source': 'http://clerk.house.gov/evs/2020/roll105.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll105.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/105.json',
#     'bill': {'bill_id': 'hres967-116',
#      'number': 'H.RES.967',
#      'sponsor_id': 'M000312',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres967.json',
#      'title': 'Providing for consideration of the resolution (H. Res. 965) authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Ordering the Previous Question',
#     'question_text': '',
#     'description': 'Providing for consideration of H. Res. 965; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-05-15',
#     'time': '11:21:00',
#     'result': 'Passed',
#     'democratic': {'yes': 219,
#      'no': 0,
#      'present': 0,
#      'not_voting': 14,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 0,
#      'no': 181,
#      'present': 0,
#      'not_voting': 15,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 219, 'no': 182, 'present': 0, 'not_voting': 29}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 104,
#     'source': 'http://clerk.house.gov/evs/2020/roll104.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll104.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/104.json',
#     'bill': {'bill_id': 'hr266-116',
#      'number': 'H.R.266',
#      'sponsor_id': 'M001143',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr266.json',
#      'title': 'Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.',
#      'latest_action': 'Became Public Law No: 116-139.'},
#     'amendment': {},
#     'question': 'On Motion to Suspend the Rules and Concur in the Senate Amendment',
#     'question_text': '',
#     'description': 'Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes',
#     'vote_type': '2/3 YEA-AND-NAY',
#     'date': '2020-04-23',
#     'time': '18:10:00',
#     'result': 'Passed',
#     'democratic': {'yes': 211,
#      'no': 1,
#      'present': 0,
#      'not_voting': 20,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 177,
#      'no': 4,
#      'present': 0,
#      'not_voting': 15,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 0, 'no': 0, 'present': 1, 'not_voting': 0},
#     'total': {'yes': 388, 'no': 5, 'present': 1, 'not_voting': 35}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 103,
#     'source': 'http://clerk.house.gov/evs/2020/roll103.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll103.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/103.json',
#     'bill': {'bill_id': 'hres938-116',
#      'number': 'H.RES.938',
#      'sponsor_id': 'M000312',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres938.json',
#      'title': 'Providing for the adoption of the resolution (H.Res. 935) establishing a Select Subcommittee on the Coronavirus Crisis as a select investigative subcommittee of the Committee on Oversight and Reform.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Agreeing to the Resolution',
#     'question_text': '',
#     'description': 'Providing for the adoption of the resolution (H.Res. 935) establishing a Select Subcommittee on the Coronavirus Crisis as a select investigative subcommittee of the Committee on Oversight and Reform',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-04-23',
#     'time': '16:39:00',
#     'result': 'Passed',
#     'democratic': {'yes': 212,
#      'no': 0,
#      'present': 0,
#      'not_voting': 20,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 0,
#      'no': 181,
#      'present': 0,
#      'not_voting': 15,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 212, 'no': 182, 'present': 0, 'not_voting': 35}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 102,
#     'source': 'http://clerk.house.gov/evs/2020/roll102.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll102.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/102.json',
#     'bill': {'bill_id': 'hr6201-116',
#      'number': 'H.R.6201',
#      'sponsor_id': 'L000480',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6201.json',
#      'title': 'Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.',
#      'latest_action': 'Engrossment Correction'},
#     'amendment': {},
#     'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#     'question_text': '',
#     'description': 'Families First Coronavirus Response Act',
#     'vote_type': '2/3 YEA-AND-NAY',
#     'date': '2020-03-13',
#     'time': '00:51:00',
#     'result': 'Passed',
#     'democratic': {'yes': 223,
#      'no': 0,
#      'present': 0,
#      'not_voting': 9,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 140,
#      'no': 40,
#      'present': 0,
#      'not_voting': 17,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 0, 'no': 0, 'present': 1, 'not_voting': 0},
#     'total': {'yes': 363, 'no': 40, 'present': 1, 'not_voting': 26}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 101,
#     'source': 'http://clerk.house.gov/evs/2020/roll101.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll101.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/101.json',
#     'bill': {'bill_id': 'sjres68-116',
#      'number': 'S.J.RES.68',
#      'sponsor_id': 'K000384',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/sjres68.json',
#      'title': 'A joint resolution to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress.',
#      'latest_action': 'Failed of passage in Senate over veto by Yea-Nay Vote. 49 - 44. Record Vote Number: 84.'},
#     'amendment': {},
#     'question': 'On Passage',
#     'question_text': '',
#     'description': 'To direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress',
#     'vote_type': 'RECORDED VOTE',
#     'date': '2020-03-11',
#     'time': '17:42:00',
#     'result': 'Passed',
#     'democratic': {'yes': 220,
#      'no': 6,
#      'present': 0,
#      'not_voting': 6,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 6,
#      'no': 180,
#      'present': 0,
#      'not_voting': 11,
#      'majority_position': 'No'},
#     'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 227, 'no': 186, 'present': 0, 'not_voting': 17}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 100,
#     'source': 'http://clerk.house.gov/evs/2020/roll100.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll100.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/100.json',
#     'bill': {'bill_id': 'sjres68-116',
#      'number': 'S.J.RES.68',
#      'sponsor_id': 'K000384',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/sjres68.json',
#      'title': 'A joint resolution to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress.',
#      'latest_action': 'Failed of passage in Senate over veto by Yea-Nay Vote. 49 - 44. Record Vote Number: 84.'},
#     'amendment': {},
#     'question': 'On Motion to Commit with Instructions',
#     'question_text': '',
#     'description': 'To direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress',
#     'vote_type': 'RECORDED VOTE',
#     'date': '2020-03-11',
#     'time': '17:35:00',
#     'result': 'Failed',
#     'democratic': {'yes': 14,
#      'no': 211,
#      'present': 0,
#      'not_voting': 7,
#      'majority_position': 'No'},
#     'republican': {'yes': 184,
#      'no': 0,
#      'present': 1,
#      'not_voting': 12,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 198, 'no': 212, 'present': 1, 'not_voting': 19}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 99,
#     'source': 'http://clerk.house.gov/evs/2020/roll099.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll099.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/99.json',
#     'bill': {'bill_id': 'hr6172-116',
#      'number': 'H.R.6172',
#      'sponsor_id': 'N000002',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6172.json',
#      'title': 'To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#      'latest_action': 'The Speaker appointed conferees: Nadler, Schiff, Lofgren, Jordan, and Nunes.'},
#     'amendment': {},
#     'question': 'On Agreeing to the Buck of Colorado Amendment to the Title',
#     'question_text': '',
#     'description': 'USA FREEDOM Reauthorization Act',
#     'vote_type': 'RECORDED VOTE',
#     'date': '2020-03-11',
#     'time': '17:13:00',
#     'result': 'Failed',
#     'democratic': {'yes': 1,
#      'no': 225,
#      'present': 0,
#      'not_voting': 6,
#      'majority_position': 'No'},
#     'republican': {'yes': 33,
#      'no': 151,
#      'present': 0,
#      'not_voting': 13,
#      'majority_position': 'No'},
#     'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 35, 'no': 376, 'present': 0, 'not_voting': 19}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 98,
#     'source': 'http://clerk.house.gov/evs/2020/roll098.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll098.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/98.json',
#     'bill': {'bill_id': 'hr6172-116',
#      'number': 'H.R.6172',
#      'sponsor_id': 'N000002',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6172.json',
#      'title': 'To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#      'latest_action': 'The Speaker appointed conferees: Nadler, Schiff, Lofgren, Jordan, and Nunes.'},
#     'amendment': {},
#     'question': 'On Passage',
#     'question_text': '',
#     'description': 'USA FREEDOM Reauthorization Act',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-03-11',
#     'time': '17:03:00',
#     'result': 'Passed',
#     'democratic': {'yes': 152,
#      'no': 75,
#      'present': 0,
#      'not_voting': 5,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 126,
#      'no': 60,
#      'present': 0,
#      'not_voting': 11,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 278, 'no': 136, 'present': 0, 'not_voting': 16}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 97,
#     'source': 'http://clerk.house.gov/evs/2020/roll097.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll097.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/97.json',
#     'bill': {'bill_id': 's760-116',
#      'number': 'S.760',
#      'sponsor_id': 'P000595',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/s760.json',
#      'title': 'A bill to enable registered apprenticeship programs to better serve veterans, and for other purposes.',
#      'latest_action': 'Became Public Law No: 116-134.'},
#     'amendment': {},
#     'question': 'On Motion to Suspend the Rules and Pass',
#     'question_text': '',
#     'description': 'Support for Veterans in Effective Apprenticeships Act of 2019',
#     'vote_type': '2/3 YEA-AND-NAY',
#     'date': '2020-03-11',
#     'time': '14:06:00',
#     'result': 'Passed',
#     'democratic': {'yes': 225,
#      'no': 0,
#      'present': 0,
#      'not_voting': 7,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 186,
#      'no': 0,
#      'present': 0,
#      'not_voting': 11,
#      'majority_position': 'Yes'},
#     'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 412, 'no': 0, 'present': 0, 'not_voting': 18}},
#    {'congress': 116,
#     'chamber': 'House',
#     'session': 2,
#     'roll_call': 96,
#     'source': 'http://clerk.house.gov/evs/2020/roll096.xml',
#     'url': 'http://clerk.house.gov/evs/2020/roll096.xml',
#     'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/96.json',
#     'bill': {'bill_id': 'hres891-116',
#      'number': 'H.RES.891',
#      'sponsor_id': 'M000312',
#      'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres891.json',
#      'title': 'Providing for consideration of the joint resolution (S.J. Res. 68) to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress; providing for consideration of the Senate amendment to the bill (H.R. 2486) to reauthorize mandatory funding programs for historically Black colleges and universities and other minority-serving institutions; providing for consideration of the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes; and for other purposes.',
#      'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#     'amendment': {},
#     'question': 'On Agreeing to the Resolution',
#     'question_text': '',
#     'description': 'Providing for consideration of S.J. Res. 68, to direct the removal of US Armed Forces from hostilities against the Islamic Republic of Iran; the Senate amendment to H.R. 2486, the FUTURE Act; and H.R. 6172, the USA FREEDOM Reauthorization Act of 2020; and for other purposes',
#     'vote_type': 'YEA-AND-NAY',
#     'date': '2020-03-11',
#     'time': '13:58:00',
#     'result': 'Passed',
#     'democratic': {'yes': 223,
#      'no': 3,
#      'present': 0,
#      'not_voting': 6,
#      'majority_position': 'Yes'},
#     'republican': {'yes': 0,
#      'no': 184,
#      'present': 0,
#      'not_voting': 13,
#      'majority_position': 'No'},
#     'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#     'total': {'yes': 223, 'no': 188, 'present': 0, 'not_voting': 19}}]}}

# %%
votes = votes_json["results"]["votes"]
votes
# Out:
# [{'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 115,
#   'source': 'http://clerk.house.gov/evs/2020/roll115.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll115.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/115.json',
#   'bill': {'bill_id': 'hr6172-116',
#    'number': 'H.R.6172',
#    'sponsor_id': 'N000002',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6172.json',
#    'title': 'To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#    'latest_action': 'The Speaker appointed conferees: Nadler, Schiff, Lofgren, Jordan, and Nunes.'},
#   'amendment': {},
#   'question': 'On Motion to Disagree to the Senate Amendments and Request a Conference',
#   'question_text': '',
#   'description': 'USA FREEDOM Reauthorization Act',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-28',
#   'time': '15:10:00',
#   'result': 'Passed',
#   'democratic': {'yes': 211,
#    'no': 21,
#    'present': 0,
#    'not_voting': 1,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 73,
#    'no': 100,
#    'present': 0,
#    'not_voting': 24,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 284, 'no': 122, 'present': 0, 'not_voting': 25}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 114,
#   'source': 'http://clerk.house.gov/evs/2020/roll114.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll114.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/114.json',
#   'bill': {'bill_id': 'hr7010-116',
#    'number': 'H.R.7010',
#    'sponsor_id': 'P000616',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr7010.json',
#    'title': 'To amend the Small Business Act and the CARES Act to modify certain provisions related to the forgiveness of loans under the paycheck protection program, to allow recipients of loan forgiveness under the paycheck protection program to defer payroll taxes, and for other purposes.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'question_text': '',
#   'description': 'Paycheck Protection Program Flexibility Act',
#   'vote_type': '2/3 YEA-AND-NAY',
#   'date': '2020-05-28',
#   'time': '13:12:00',
#   'result': 'Passed',
#   'democratic': {'yes': 233,
#    'no': 0,
#    'present': 0,
#    'not_voting': 0,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 183,
#    'no': 1,
#    'present': 0,
#    'not_voting': 13,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 417, 'no': 1, 'present': 0, 'not_voting': 13}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 113,
#   'source': 'http://clerk.house.gov/evs/2020/roll113.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll113.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/113.json',
#   'bill': {'bill_id': 'hr6782-116',
#    'number': 'H.R.6782',
#    'sponsor_id': 'P000616',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6782.json',
#    'title': 'To require the Administrator of the Small Business Administration to submit a report on recipients of assistance under the paycheck protection program and the economic injury disaster loan program, and for other purposes.',
#    'latest_action': 'On motion to suspend the rules and pass the bill, as amended Failed by the Yeas and Nays: (2/3 required): 269 - 147 (Roll no. 113).'},
#   'amendment': {},
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'question_text': '',
#   'description': 'TRUTH Act',
#   'vote_type': '2/3 YEA-AND-NAY',
#   'date': '2020-05-28',
#   'time': '11:59:00',
#   'result': 'Failed',
#   'democratic': {'yes': 231,
#    'no': 0,
#    'present': 0,
#    'not_voting': 2,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 38,
#    'no': 146,
#    'present': 0,
#    'not_voting': 13,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 269, 'no': 147, 'present': 0, 'not_voting': 15}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 112,
#   'source': 'http://clerk.house.gov/evs/2020/roll112.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll112.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/112.json',
#   'bill': {'bill_id': 'hres981-116',
#    'number': 'H.RES.981',
#    'sponsor_id': 'M000312',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres981.json',
#    'title': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Agreeing to the Resolution',
#   'question_text': '',
#   'description': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-27',
#   'time': '20:05:00',
#   'result': 'Passed',
#   'democratic': {'yes': 228,
#    'no': 5,
#    'present': 0,
#    'not_voting': 0,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 0,
#    'no': 183,
#    'present': 0,
#    'not_voting': 14,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 228, 'no': 189, 'present': 0, 'not_voting': 14}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 111,
#   'source': 'http://clerk.house.gov/evs/2020/roll111.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll111.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/111.json',
#   'bill': {'bill_id': 'hres981-116',
#    'number': 'H.RES.981',
#    'sponsor_id': 'M000312',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres981.json',
#    'title': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Ordering the Previous Question',
#   'question_text': '',
#   'description': 'Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-27',
#   'time': '18:57:00',
#   'result': 'Passed',
#   'democratic': {'yes': 232,
#    'no': 0,
#    'present': 0,
#    'not_voting': 1,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 0,
#    'no': 181,
#    'present': 0,
#    'not_voting': 16,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 232, 'no': 182, 'present': 0, 'not_voting': 17}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 110,
#   'source': 'http://clerk.house.gov/evs/2020/roll110.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll110.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/110.json',
#   'bill': {'bill_id': 's3744-116',
#    'number': 'S.3744',
#    'sponsor_id': 'R000595',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/s3744.json',
#    'title': 'A bill to condemn gross human rights violations of ethnic Turkic Muslims in Xinjiang, and calling for an end to arbitrary detention, torture, and harassment of these communities inside and outside China.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'question_text': '',
#   'description': 'Uyghur Human Rights Policy Act',
#   'vote_type': '2/3 YEA-AND-NAY',
#   'date': '2020-05-27',
#   'time': '17:44:00',
#   'result': 'Passed',
#   'democratic': {'yes': 231,
#    'no': 0,
#    'present': 0,
#    'not_voting': 2,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 181,
#    'no': 1,
#    'present': 0,
#    'not_voting': 15,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 413, 'no': 1, 'present': 0, 'not_voting': 17}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 109,
#   'source': 'http://clerk.house.gov/evs/2020/roll109.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll109.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/109.json',
#   'bill': {'bill_id': 'hr6800-116',
#    'number': 'H.R.6800',
#    'sponsor_id': 'L000480',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6800.json',
#    'title': 'Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.',
#    'latest_action': 'Read the first time. Placed on Senate Legislative Calendar under Read the First Time.'},
#   'amendment': {},
#   'question': 'On Passage',
#   'question_text': '',
#   'description': 'HEROES Act',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-15',
#   'time': '21:24:00',
#   'result': 'Passed',
#   'democratic': {'yes': 207,
#    'no': 14,
#    'present': 0,
#    'not_voting': 12,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 1,
#    'no': 184,
#    'present': 0,
#    'not_voting': 11,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 208, 'no': 199, 'present': 0, 'not_voting': 23}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 108,
#   'source': 'http://clerk.house.gov/evs/2020/roll108.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll108.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/108.json',
#   'bill': {'bill_id': 'hr6800-116',
#    'number': 'H.R.6800',
#    'sponsor_id': 'L000480',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6800.json',
#    'title': 'Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.',
#    'latest_action': 'Read the first time. Placed on Senate Legislative Calendar under Read the First Time.'},
#   'amendment': {},
#   'question': 'On Motion to Recommit with Instructions',
#   'question_text': '',
#   'description': 'HEROES Act',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-15',
#   'time': '20:22:00',
#   'result': 'Failed',
#   'democratic': {'yes': 13,
#    'no': 208,
#    'present': 0,
#    'not_voting': 12,
#    'majority_position': 'No'},
#   'republican': {'yes': 185,
#    'no': 0,
#    'present': 0,
#    'not_voting': 11,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 198, 'no': 209, 'present': 0, 'not_voting': 23}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 107,
#   'source': 'http://clerk.house.gov/evs/2020/roll107.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll107.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/107.json',
#   'bill': {'bill_id': 'hres965-116',
#    'number': 'H.RES.965',
#    'sponsor_id': 'M000312',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres965.json',
#    'title': 'Authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Agreeing to the Resolution',
#   'question_text': '',
#   'description': 'Authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-15',
#   'time': '19:15:00',
#   'result': 'Passed',
#   'democratic': {'yes': 217,
#    'no': 3,
#    'present': 0,
#    'not_voting': 13,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 0,
#    'no': 185,
#    'present': 0,
#    'not_voting': 11,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 217, 'no': 189, 'present': 0, 'not_voting': 24}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 106,
#   'source': 'http://clerk.house.gov/evs/2020/roll106.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll106.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/106.json',
#   'bill': {'bill_id': 'hres967-116',
#    'number': 'H.RES.967',
#    'sponsor_id': 'M000312',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres967.json',
#    'title': 'Providing for consideration of the resolution (H. Res. 965) authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Agreeing to the Resolution',
#   'question_text': '',
#   'description': 'Providing for consideration of H. Res. 965; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-15',
#   'time': '12:28:00',
#   'result': 'Passed',
#   'democratic': {'yes': 207,
#    'no': 14,
#    'present': 0,
#    'not_voting': 12,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 0,
#    'no': 184,
#    'present': 0,
#    'not_voting': 12,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 207, 'no': 199, 'present': 0, 'not_voting': 24}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 105,
#   'source': 'http://clerk.house.gov/evs/2020/roll105.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll105.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/105.json',
#   'bill': {'bill_id': 'hres967-116',
#    'number': 'H.RES.967',
#    'sponsor_id': 'M000312',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres967.json',
#    'title': 'Providing for consideration of the resolution (H. Res. 965) authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Ordering the Previous Question',
#   'question_text': '',
#   'description': 'Providing for consideration of H. Res. 965; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-05-15',
#   'time': '11:21:00',
#   'result': 'Passed',
#   'democratic': {'yes': 219,
#    'no': 0,
#    'present': 0,
#    'not_voting': 14,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 0,
#    'no': 181,
#    'present': 0,
#    'not_voting': 15,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 219, 'no': 182, 'present': 0, 'not_voting': 29}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 104,
#   'source': 'http://clerk.house.gov/evs/2020/roll104.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll104.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/104.json',
#   'bill': {'bill_id': 'hr266-116',
#    'number': 'H.R.266',
#    'sponsor_id': 'M001143',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr266.json',
#    'title': 'Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.',
#    'latest_action': 'Became Public Law No: 116-139.'},
#   'amendment': {},
#   'question': 'On Motion to Suspend the Rules and Concur in the Senate Amendment',
#   'question_text': '',
#   'description': 'Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes',
#   'vote_type': '2/3 YEA-AND-NAY',
#   'date': '2020-04-23',
#   'time': '18:10:00',
#   'result': 'Passed',
#   'democratic': {'yes': 211,
#    'no': 1,
#    'present': 0,
#    'not_voting': 20,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 177,
#    'no': 4,
#    'present': 0,
#    'not_voting': 15,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 0, 'no': 0, 'present': 1, 'not_voting': 0},
#   'total': {'yes': 388, 'no': 5, 'present': 1, 'not_voting': 35}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 103,
#   'source': 'http://clerk.house.gov/evs/2020/roll103.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll103.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/103.json',
#   'bill': {'bill_id': 'hres938-116',
#    'number': 'H.RES.938',
#    'sponsor_id': 'M000312',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres938.json',
#    'title': 'Providing for the adoption of the resolution (H.Res. 935) establishing a Select Subcommittee on the Coronavirus Crisis as a select investigative subcommittee of the Committee on Oversight and Reform.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Agreeing to the Resolution',
#   'question_text': '',
#   'description': 'Providing for the adoption of the resolution (H.Res. 935) establishing a Select Subcommittee on the Coronavirus Crisis as a select investigative subcommittee of the Committee on Oversight and Reform',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-04-23',
#   'time': '16:39:00',
#   'result': 'Passed',
#   'democratic': {'yes': 212,
#    'no': 0,
#    'present': 0,
#    'not_voting': 20,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 0,
#    'no': 181,
#    'present': 0,
#    'not_voting': 15,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 212, 'no': 182, 'present': 0, 'not_voting': 35}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 102,
#   'source': 'http://clerk.house.gov/evs/2020/roll102.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll102.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/102.json',
#   'bill': {'bill_id': 'hr6201-116',
#    'number': 'H.R.6201',
#    'sponsor_id': 'L000480',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6201.json',
#    'title': 'Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.',
#    'latest_action': 'Engrossment Correction'},
#   'amendment': {},
#   'question': 'On Motion to Suspend the Rules and Pass, as Amended',
#   'question_text': '',
#   'description': 'Families First Coronavirus Response Act',
#   'vote_type': '2/3 YEA-AND-NAY',
#   'date': '2020-03-13',
#   'time': '00:51:00',
#   'result': 'Passed',
#   'democratic': {'yes': 223,
#    'no': 0,
#    'present': 0,
#    'not_voting': 9,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 140,
#    'no': 40,
#    'present': 0,
#    'not_voting': 17,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 0, 'no': 0, 'present': 1, 'not_voting': 0},
#   'total': {'yes': 363, 'no': 40, 'present': 1, 'not_voting': 26}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 101,
#   'source': 'http://clerk.house.gov/evs/2020/roll101.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll101.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/101.json',
#   'bill': {'bill_id': 'sjres68-116',
#    'number': 'S.J.RES.68',
#    'sponsor_id': 'K000384',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/sjres68.json',
#    'title': 'A joint resolution to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress.',
#    'latest_action': 'Failed of passage in Senate over veto by Yea-Nay Vote. 49 - 44. Record Vote Number: 84.'},
#   'amendment': {},
#   'question': 'On Passage',
#   'question_text': '',
#   'description': 'To direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress',
#   'vote_type': 'RECORDED VOTE',
#   'date': '2020-03-11',
#   'time': '17:42:00',
#   'result': 'Passed',
#   'democratic': {'yes': 220,
#    'no': 6,
#    'present': 0,
#    'not_voting': 6,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 6,
#    'no': 180,
#    'present': 0,
#    'not_voting': 11,
#    'majority_position': 'No'},
#   'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 227, 'no': 186, 'present': 0, 'not_voting': 17}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 100,
#   'source': 'http://clerk.house.gov/evs/2020/roll100.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll100.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/100.json',
#   'bill': {'bill_id': 'sjres68-116',
#    'number': 'S.J.RES.68',
#    'sponsor_id': 'K000384',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/sjres68.json',
#    'title': 'A joint resolution to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress.',
#    'latest_action': 'Failed of passage in Senate over veto by Yea-Nay Vote. 49 - 44. Record Vote Number: 84.'},
#   'amendment': {},
#   'question': 'On Motion to Commit with Instructions',
#   'question_text': '',
#   'description': 'To direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress',
#   'vote_type': 'RECORDED VOTE',
#   'date': '2020-03-11',
#   'time': '17:35:00',
#   'result': 'Failed',
#   'democratic': {'yes': 14,
#    'no': 211,
#    'present': 0,
#    'not_voting': 7,
#    'majority_position': 'No'},
#   'republican': {'yes': 184,
#    'no': 0,
#    'present': 1,
#    'not_voting': 12,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 198, 'no': 212, 'present': 1, 'not_voting': 19}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 99,
#   'source': 'http://clerk.house.gov/evs/2020/roll099.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll099.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/99.json',
#   'bill': {'bill_id': 'hr6172-116',
#    'number': 'H.R.6172',
#    'sponsor_id': 'N000002',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6172.json',
#    'title': 'To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#    'latest_action': 'The Speaker appointed conferees: Nadler, Schiff, Lofgren, Jordan, and Nunes.'},
#   'amendment': {},
#   'question': 'On Agreeing to the Buck of Colorado Amendment to the Title',
#   'question_text': '',
#   'description': 'USA FREEDOM Reauthorization Act',
#   'vote_type': 'RECORDED VOTE',
#   'date': '2020-03-11',
#   'time': '17:13:00',
#   'result': 'Failed',
#   'democratic': {'yes': 1,
#    'no': 225,
#    'present': 0,
#    'not_voting': 6,
#    'majority_position': 'No'},
#   'republican': {'yes': 33,
#    'no': 151,
#    'present': 0,
#    'not_voting': 13,
#    'majority_position': 'No'},
#   'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 35, 'no': 376, 'present': 0, 'not_voting': 19}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 98,
#   'source': 'http://clerk.house.gov/evs/2020/roll098.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll098.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/98.json',
#   'bill': {'bill_id': 'hr6172-116',
#    'number': 'H.R.6172',
#    'sponsor_id': 'N000002',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hr6172.json',
#    'title': 'To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.',
#    'latest_action': 'The Speaker appointed conferees: Nadler, Schiff, Lofgren, Jordan, and Nunes.'},
#   'amendment': {},
#   'question': 'On Passage',
#   'question_text': '',
#   'description': 'USA FREEDOM Reauthorization Act',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-03-11',
#   'time': '17:03:00',
#   'result': 'Passed',
#   'democratic': {'yes': 152,
#    'no': 75,
#    'present': 0,
#    'not_voting': 5,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 126,
#    'no': 60,
#    'present': 0,
#    'not_voting': 11,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 278, 'no': 136, 'present': 0, 'not_voting': 16}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 97,
#   'source': 'http://clerk.house.gov/evs/2020/roll097.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll097.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/97.json',
#   'bill': {'bill_id': 's760-116',
#    'number': 'S.760',
#    'sponsor_id': 'P000595',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/s760.json',
#    'title': 'A bill to enable registered apprenticeship programs to better serve veterans, and for other purposes.',
#    'latest_action': 'Became Public Law No: 116-134.'},
#   'amendment': {},
#   'question': 'On Motion to Suspend the Rules and Pass',
#   'question_text': '',
#   'description': 'Support for Veterans in Effective Apprenticeships Act of 2019',
#   'vote_type': '2/3 YEA-AND-NAY',
#   'date': '2020-03-11',
#   'time': '14:06:00',
#   'result': 'Passed',
#   'democratic': {'yes': 225,
#    'no': 0,
#    'present': 0,
#    'not_voting': 7,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 186,
#    'no': 0,
#    'present': 0,
#    'not_voting': 11,
#    'majority_position': 'Yes'},
#   'independent': {'yes': 1, 'no': 0, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 412, 'no': 0, 'present': 0, 'not_voting': 18}},
#  {'congress': 116,
#   'chamber': 'House',
#   'session': 2,
#   'roll_call': 96,
#   'source': 'http://clerk.house.gov/evs/2020/roll096.xml',
#   'url': 'http://clerk.house.gov/evs/2020/roll096.xml',
#   'vote_uri': 'https://api.propublica.org/congress/v1/116/house/sessions/2/votes/96.json',
#   'bill': {'bill_id': 'hres891-116',
#    'number': 'H.RES.891',
#    'sponsor_id': 'M000312',
#    'api_uri': 'https://api.propublica.org/congress/v1/116/bills/hres891.json',
#    'title': 'Providing for consideration of the joint resolution (S.J. Res. 68) to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress; providing for consideration of the Senate amendment to the bill (H.R. 2486) to reauthorize mandatory funding programs for historically Black colleges and universities and other minority-serving institutions; providing for consideration of the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes; and for other purposes.',
#    'latest_action': 'Motion to reconsider laid on the table Agreed to without objection.'},
#   'amendment': {},
#   'question': 'On Agreeing to the Resolution',
#   'question_text': '',
#   'description': 'Providing for consideration of S.J. Res. 68, to direct the removal of US Armed Forces from hostilities against the Islamic Republic of Iran; the Senate amendment to H.R. 2486, the FUTURE Act; and H.R. 6172, the USA FREEDOM Reauthorization Act of 2020; and for other purposes',
#   'vote_type': 'YEA-AND-NAY',
#   'date': '2020-03-11',
#   'time': '13:58:00',
#   'result': 'Passed',
#   'democratic': {'yes': 223,
#    'no': 3,
#    'present': 0,
#    'not_voting': 6,
#    'majority_position': 'Yes'},
#   'republican': {'yes': 0,
#    'no': 184,
#    'present': 0,
#    'not_voting': 13,
#    'majority_position': 'No'},
#   'independent': {'yes': 0, 'no': 1, 'present': 0, 'not_voting': 0},
#   'total': {'yes': 223, 'no': 188, 'present': 0, 'not_voting': 19}}]

# %%
len(votes)
# Out:
# 20

# %%
for x in votes:
    try:
        print (f"Title: {x['bill']['title']}")
        print(f"Description: {x['description']}")
        print(f"Chamber: {x['chamber']}")
        print(f"Result: {x['result']}")
        print("-------")
    except:
        print ("Error: Not a Bill")
        print ("-------")
# Out:
# Title: To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.
# Description: USA FREEDOM Reauthorization Act
# Chamber: House
# Result: Passed
# -------
# Title: To amend the Small Business Act and the CARES Act to modify certain provisions related to the forgiveness of loans under the paycheck protection program, to allow recipients of loan forgiveness under the paycheck protection program to defer payroll taxes, and for other purposes.
# Description: Paycheck Protection Program Flexibility Act
# Chamber: House
# Result: Passed
# -------
# Title: To require the Administrator of the Small Business Administration to submit a report on recipients of assistance under the paycheck protection program and the economic injury disaster loan program, and for other purposes.
# Description: TRUTH Act
# Chamber: House
# Result: Failed
# -------
# Title: Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.
# Description: Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes
# Chamber: House
# Result: Passed
# -------
# Title: Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.
# Description: Providing for consideration of the Senate amendments to the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes
# Chamber: House
# Result: Passed
# -------
# Title: A bill to condemn gross human rights violations of ethnic Turkic Muslims in Xinjiang, and calling for an end to arbitrary detention, torture, and harassment of these communities inside and outside China.
# Description: Uyghur Human Rights Policy Act
# Chamber: House
# Result: Passed
# -------
# Title: Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.
# Description: HEROES Act
# Chamber: House
# Result: Passed
# -------
# Title: Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.
# Description: HEROES Act
# Chamber: House
# Result: Failed
# -------
# Title: Authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes.
# Description: Authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes
# Chamber: House
# Result: Passed
# -------
# Title: Providing for consideration of the resolution (H. Res. 965) authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes.
# Description: Providing for consideration of H. Res. 965; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes
# Chamber: House
# Result: Passed
# -------
# Title: Providing for consideration of the resolution (H. Res. 965) authorizing remote voting by proxy in the House of Representatives and providing for official remote committee proceedings during a public health emergency due to a novel coronavirus, and for other purposes; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes.
# Description: Providing for consideration of H. Res. 965; providing for consideration of the bill (H.R. 6800) making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes; providing for proceedings during the period from May 19, 2020, through July 21, 2020; and for other purposes
# Chamber: House
# Result: Passed
# -------
# Title: Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes.
# Description: Making appropriations for the Department of the Interior, environment, and related agencies for the fiscal year ending September 30, 2019, and for other purposes
# Chamber: House
# Result: Passed
# -------
# Title: Providing for the adoption of the resolution (H.Res. 935) establishing a Select Subcommittee on the Coronavirus Crisis as a select investigative subcommittee of the Committee on Oversight and Reform.
# Description: Providing for the adoption of the resolution (H.Res. 935) establishing a Select Subcommittee on the Coronavirus Crisis as a select investigative subcommittee of the Committee on Oversight and Reform
# Chamber: House
# Result: Passed
# -------
# Title: Making emergency supplemental appropriations for the fiscal year ending September 30, 2020, and for other purposes.
# Description: Families First Coronavirus Response Act
# Chamber: House
# Result: Passed
# -------
# Title: A joint resolution to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress.
# Description: To direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress
# Chamber: House
# Result: Passed
# -------
# Title: A joint resolution to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress.
# Description: To direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress
# Chamber: House
# Result: Failed
# -------
# Title: To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.
# Description: USA FREEDOM Reauthorization Act
# Chamber: House
# Result: Failed
# -------
# Title: To amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes.
# Description: USA FREEDOM Reauthorization Act
# Chamber: House
# Result: Passed
# -------
# Title: A bill to enable registered apprenticeship programs to better serve veterans, and for other purposes.
# Description: Support for Veterans in Effective Apprenticeships Act of 2019
# Chamber: House
# Result: Passed
# -------
# Title: Providing for consideration of the joint resolution (S.J. Res. 68) to direct the removal of United States Armed Forces from hostilities against the Islamic Republic of Iran that have not been authorized by Congress; providing for consideration of the Senate amendment to the bill (H.R. 2486) to reauthorize mandatory funding programs for historically Black colleges and universities and other minority-serving institutions; providing for consideration of the bill (H.R. 6172) to amend the Foreign Intelligence Surveillance Act of 1978 to prohibit the production of certain business records, and for other purposes; and for other purposes.
# Description: Providing for consideration of S.J. Res. 68, to direct the removal of US Armed Forces from hostilities against the Islamic Republic of Iran; the Senate amendment to H.R. 2486, the FUTURE Act; and H.R. 6172, the USA FREEDOM Reauthorization Act of 2020; and for other purposes
# Chamber: House
# Result: Passed
# -------

# %%
db.votes.drop()
db.votes.insert_many(votes)

# %%
members_url = "https://api.propublica.org/congress/v1/116/house/members.json"
members_r = requests.get(members_url, headers={"X-API-Key": key})

# %%
members_json = members_r.json()
members_json
# Out:
# {'status': 'OK',
#  'copyright': ' Copyright (c) 2020 Pro Publica Inc. All Rights Reserved.',
#  'results': [{'congress': '116',
#    'chamber': 'House',
#    'num_results': 448,
#    'offset': 0,
#    'members': [{'id': 'A000374',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000374.json',
#      'first_name': 'Ralph',
#      'middle_name': None,
#      'last_name': 'Abraham',
#      'suffix': None,
#      'date_of_birth': '1954-09-16',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': '',
#      'twitter_account': 'RepAbraham',
#      'facebook_account': 'CongressmanRalphAbraham',
#      'youtube_account': None,
#      'govtrack_id': '412630',
#      'cspan_id': '76236',
#      'votesmart_id': '155414',
#      'icpsr_id': '21522',
#      'crp_id': 'N00036633',
#      'google_entity_id': '/m/012dwd7_',
#      'fec_candidate_id': 'H4LA05221',
#      'url': 'https://abraham.house.gov',
#      'rss_url': 'https://abraham.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+15',
#      'dw_nominate': 0.54,
#      'ideal_point': None,
#      'seniority': '6',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 264,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:22 -0400',
#      'ocd_id': 'ocd-division/country:us/state:la/cd:5',
#      'office': '417 Cannon House Office Building',
#      'phone': '202-225-8490',
#      'fax': None,
#      'state': 'LA',
#      'district': '5',
#      'at_large': False,
#      'geoid': '2205',
#      'missed_votes_pct': 32.35,
#      'votes_with_party_pct': 94.7,
#      'votes_against_party_pct': 5.12},
#     {'id': 'A000370',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000370.json',
#      'first_name': 'Alma',
#      'middle_name': None,
#      'last_name': 'Adams',
#      'suffix': None,
#      'date_of_birth': '1946-05-27',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepAdams',
#      'facebook_account': 'CongresswomanAdams',
#      'youtube_account': None,
#      'govtrack_id': '412607',
#      'cspan_id': '76386',
#      'votesmart_id': '5935',
#      'icpsr_id': '21545',
#      'crp_id': 'N00035451',
#      'google_entity_id': '/m/02b45d',
#      'fec_candidate_id': 'H4NC12100',
#      'url': 'https://adams.house.gov',
#      'rss_url': 'https://adams.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+18',
#      'dw_nominate': -0.466,
#      'ideal_point': None,
#      'seniority': '8',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 26,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:47 -0400',
#      'ocd_id': 'ocd-division/country:us/state:nc/cd:12',
#      'office': '2436 Rayburn House Office Building',
#      'phone': '202-225-1510',
#      'fax': None,
#      'state': 'NC',
#      'district': '12',
#      'at_large': False,
#      'geoid': '3712',
#      'missed_votes_pct': 3.19,
#      'votes_with_party_pct': 99.11,
#      'votes_against_party_pct': 0.76},
#     {'id': 'A000055',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000055.json',
#      'first_name': 'Robert',
#      'middle_name': 'B.',
#      'last_name': 'Aderholt',
#      'suffix': None,
#      'date_of_birth': '1965-07-22',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'Robert_Aderholt',
#      'facebook_account': 'RobertAderholt',
#      'youtube_account': 'RobertAderholt',
#      'govtrack_id': '400004',
#      'cspan_id': '45516',
#      'votesmart_id': '441',
#      'icpsr_id': '29701',
#      'crp_id': 'N00003028',
#      'google_entity_id': '/m/024p03',
#      'fec_candidate_id': 'H6AL04098',
#      'url': 'https://aderholt.house.gov',
#      'rss_url': 'https://aderholt.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+30',
#      'dw_nominate': 0.367,
#      'ideal_point': None,
#      'seniority': '24',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 41,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:36 -0400',
#      'ocd_id': 'ocd-division/country:us/state:al/cd:4',
#      'office': '1203 Longworth House Office Building',
#      'phone': '202-225-4876',
#      'fax': None,
#      'state': 'AL',
#      'district': '4',
#      'at_large': False,
#      'geoid': '0104',
#      'missed_votes_pct': 5.02,
#      'votes_with_party_pct': 93.5,
#      'votes_against_party_pct': 6.37},
#     {'id': 'A000371',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000371.json',
#      'first_name': 'Pete',
#      'middle_name': None,
#      'last_name': 'Aguilar',
#      'suffix': None,
#      'date_of_birth': '1979-06-19',
#      'gender': 'M',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'reppeteaguilar',
#      'facebook_account': 'reppeteaguilar',
#      'youtube_account': None,
#      'govtrack_id': '412615',
#      'cspan_id': '79994',
#      'votesmart_id': '70114',
#      'icpsr_id': '21506',
#      'crp_id': 'N00033997',
#      'google_entity_id': '/m/0jwv0xf',
#      'fec_candidate_id': 'H2CA31125',
#      'url': 'https://aguilar.house.gov',
#      'rss_url': 'https://aguilar.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+8',
#      'dw_nominate': -0.291,
#      'ideal_point': None,
#      'seniority': '6',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 8,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:18 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ca/cd:31',
#      'office': '109 Cannon House Office Building',
#      'phone': '202-225-3201',
#      'fax': None,
#      'state': 'CA',
#      'district': '31',
#      'at_large': False,
#      'geoid': '0631',
#      'missed_votes_pct': 0.98,
#      'votes_with_party_pct': 97.39,
#      'votes_against_party_pct': 2.48},
#     {'id': 'A000372',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000372.json',
#      'first_name': 'Rick',
#      'middle_name': None,
#      'last_name': 'Allen',
#      'suffix': None,
#      'date_of_birth': '1951-11-07',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'reprickallen',
#      'facebook_account': 'CongressmanRickAllen',
#      'youtube_account': None,
#      'govtrack_id': '412625',
#      'cspan_id': '62545',
#      'votesmart_id': '136062',
#      'icpsr_id': '21516',
#      'crp_id': 'N00033720',
#      'google_entity_id': '/m/0127y9dk',
#      'fec_candidate_id': 'H2GA12121',
#      'url': 'https://allen.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+9',
#      'dw_nominate': 0.677,
#      'ideal_point': None,
#      'seniority': '6',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 2,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:02:23 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ga/cd:12',
#      'office': '2400 Rayburn House Office Building',
#      'phone': '202-225-2823',
#      'fax': None,
#      'state': 'GA',
#      'district': '12',
#      'at_large': False,
#      'geoid': '1312',
#      'missed_votes_pct': 0.25,
#      'votes_with_party_pct': 91.95,
#      'votes_against_party_pct': 7.93},
#     {'id': 'A000376',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000376.json',
#      'first_name': 'Colin',
#      'middle_name': None,
#      'last_name': 'Allred',
#      'suffix': None,
#      'date_of_birth': '1983-04-15',
#      'gender': 'M',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepColinAllred',
#      'facebook_account': None,
#      'youtube_account': None,
#      'govtrack_id': '412828',
#      'cspan_id': None,
#      'votesmart_id': '177357',
#      'icpsr_id': None,
#      'crp_id': 'N00040989',
#      'google_entity_id': '/m/03d066b',
#      'fec_candidate_id': 'H8TX32098',
#      'url': 'https://allred.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+5',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '2',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 29,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:44 -0400',
#      'ocd_id': 'ocd-division/country:us/state:tx/cd:32',
#      'office': '328 Cannon House Office Building',
#      'phone': '202-225-2231',
#      'fax': None,
#      'state': 'TX',
#      'district': '32',
#      'at_large': False,
#      'geoid': '4832',
#      'missed_votes_pct': 3.55,
#      'votes_with_party_pct': 97.58,
#      'votes_against_party_pct': 2.29},
#     {'id': 'A000367',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000367.json',
#      'first_name': 'Justin',
#      'middle_name': None,
#      'last_name': 'Amash',
#      'suffix': None,
#      'date_of_birth': '1980-04-18',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': '',
#      'twitter_account': None,
#      'facebook_account': 'repjustinamash',
#      'youtube_account': 'repjustinamash',
#      'govtrack_id': '412438',
#      'cspan_id': '1033767',
#      'votesmart_id': '105566',
#      'icpsr_id': '21143',
#      'crp_id': 'N00031938',
#      'google_entity_id': '/m/0c00p_n',
#      'fec_candidate_id': 'H0MI03126',
#      'url': 'https://amash.house.gov',
#      'rss_url': 'https://amash.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': False,
#      'cook_pvi': None,
#      'dw_nominate': 0.654,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 430,
#      'missed_votes': 0,
#      'total_present': 5,
#      'last_updated': '2020-05-28 16:13:34 -0400',
#      'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#      'office': '106 Cannon House Office Building',
#      'phone': '202-225-3831',
#      'fax': None,
#      'state': 'MI',
#      'district': '3',
#      'at_large': False,
#      'geoid': '2603',
#      'missed_votes_pct': 0.0,
#      'votes_with_party_pct': 61.97,
#      'votes_against_party_pct': 37.79},
#     {'id': 'A000367',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000367.json',
#      'first_name': 'Justin',
#      'middle_name': None,
#      'last_name': 'Amash',
#      'suffix': None,
#      'date_of_birth': '1980-04-18',
#      'gender': 'M',
#      'party': 'I',
#      'leadership_role': None,
#      'twitter_account': None,
#      'facebook_account': 'repjustinamash',
#      'youtube_account': 'repjustinamash',
#      'govtrack_id': '412438',
#      'cspan_id': '1033767',
#      'votesmart_id': '105566',
#      'icpsr_id': '21143',
#      'crp_id': 'N00031938',
#      'google_entity_id': '/m/0c00p_n',
#      'fec_candidate_id': '',
#      'url': 'https://amash.house.gov',
#      'rss_url': 'https://amash.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+6',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 386,
#      'missed_votes': 0,
#      'total_present': 6,
#      'last_updated': '2020-06-02 18:02:06 -0400',
#      'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#      'office': None,
#      'phone': None,
#      'fax': None,
#      'state': 'MI',
#      'district': '3',
#      'at_large': False,
#      'geoid': '2603',
#      'missed_votes_pct': 0.0,
#      'votes_with_party_pct': 57.18,
#      'votes_against_party_pct': 42.82},
#     {'id': 'A000369',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000369.json',
#      'first_name': 'Mark',
#      'middle_name': None,
#      'last_name': 'Amodei',
#      'suffix': None,
#      'date_of_birth': '1958-06-12',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'MarkAmodeiNV2',
#      'facebook_account': 'MarkAmodeiNV2',
#      'youtube_account': 'markamodeinv2',
#      'govtrack_id': '412500',
#      'cspan_id': '62817',
#      'votesmart_id': '12537',
#      'icpsr_id': '21196',
#      'crp_id': 'N00031177',
#      'google_entity_id': '/m/03bzdkn',
#      'fec_candidate_id': 'H2NV02395',
#      'url': 'https://amodei.house.gov',
#      'rss_url': 'https://amodei.house.gov/rss/news-releases.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+7',
#      'dw_nominate': 0.381,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 22,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:51 -0400',
#      'ocd_id': 'ocd-division/country:us/state:nv/cd:2',
#      'office': '104 Cannon House Office Building',
#      'phone': '202-225-6155',
#      'fax': None,
#      'state': 'NV',
#      'district': '2',
#      'at_large': False,
#      'geoid': '3202',
#      'missed_votes_pct': 2.7,
#      'votes_with_party_pct': 92.25,
#      'votes_against_party_pct': 7.62},
#     {'id': 'A000377',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000377.json',
#      'first_name': 'Kelly',
#      'middle_name': None,
#      'last_name': 'Armstrong',
#      'suffix': None,
#      'date_of_birth': '1976-10-08',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepArmstrongND',
#      'facebook_account': None,
#      'youtube_account': None,
#      'govtrack_id': '412794',
#      'cspan_id': None,
#      'votesmart_id': '139338',
#      'icpsr_id': None,
#      'crp_id': 'N00042868',
#      'google_entity_id': '/g/11hcszksh3',
#      'fec_candidate_id': 'H8ND00096',
#      'url': 'https://armstrong.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+16',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '2',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 28,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:45 -0400',
#      'ocd_id': 'ocd-division/country:us/state:nd/cd:1',
#      'office': '1004 Longworth House Office Building',
#      'phone': '202-225-2611',
#      'fax': None,
#      'state': 'ND',
#      'district': 'At-Large',
#      'at_large': True,
#      'geoid': '3800',
#      'missed_votes_pct': 3.43,
#      'votes_with_party_pct': 93.21,
#      'votes_against_party_pct': 6.66},
#     {'id': 'A000375',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000375.json',
#      'first_name': 'Jodey',
#      'middle_name': None,
#      'last_name': 'Arrington',
#      'suffix': None,
#      'date_of_birth': '1972-03-09',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepArrington',
#      'facebook_account': 'JodeyArrington',
#      'youtube_account': None,
#      'govtrack_id': '412726',
#      'cspan_id': '1016482',
#      'votesmart_id': '155685',
#      'icpsr_id': '21700',
#      'crp_id': 'N00038285',
#      'google_entity_id': '/m/0g9_f_1',
#      'fec_candidate_id': 'H6TX19099',
#      'url': 'https://arrington.house.gov',
#      'rss_url': 'https://arrington.house.gov/feed/',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+27',
#      'dw_nominate': 0.625,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 13,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:05 -0400',
#      'ocd_id': 'ocd-division/country:us/state:tx/cd:19',
#      'office': '1029 Longworth House Office Building',
#      'phone': '202-225-4005',
#      'fax': None,
#      'state': 'TX',
#      'district': '19',
#      'at_large': False,
#      'geoid': '4819',
#      'missed_votes_pct': 1.59,
#      'votes_with_party_pct': 90.7,
#      'votes_against_party_pct': 9.17},
#     {'id': 'A000378',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/A000378.json',
#      'first_name': 'Cynthia',
#      'middle_name': None,
#      'last_name': 'Axne',
#      'suffix': None,
#      'date_of_birth': '1965-04-20',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepCindyAxne',
#      'facebook_account': None,
#      'youtube_account': None,
#      'govtrack_id': '412772',
#      'cspan_id': None,
#      'votesmart_id': '179226',
#      'icpsr_id': None,
#      'crp_id': 'N00041104',
#      'google_entity_id': '/g/11fgktcgcb',
#      'fec_candidate_id': 'H8IA03124',
#      'url': 'https://axne.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+1',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '2',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 17,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:58 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ia/cd:3',
#      'office': '330 Cannon House Office Building',
#      'phone': '202-225-5476',
#      'fax': None,
#      'state': 'IA',
#      'district': '3',
#      'at_large': False,
#      'geoid': '1903',
#      'missed_votes_pct': 2.08,
#      'votes_with_party_pct': 93.73,
#      'votes_against_party_pct': 6.15},
#     {'id': 'B001291',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001291.json',
#      'first_name': 'Brian',
#      'middle_name': None,
#      'last_name': 'Babin',
#      'suffix': None,
#      'date_of_birth': '1948-03-23',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepBrianBabin',
#      'facebook_account': 'RepBrianBabin',
#      'youtube_account': None,
#      'govtrack_id': '412655',
#      'cspan_id': '44883',
#      'votesmart_id': '360',
#      'icpsr_id': '21551',
#      'crp_id': 'N00005736',
#      'google_entity_id': '/m/010qgj35',
#      'fec_candidate_id': 'H6TX02079',
#      'url': 'https://babin.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+26',
#      'dw_nominate': 0.698,
#      'ideal_point': None,
#      'seniority': '6',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 29,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:44 -0400',
#      'ocd_id': 'ocd-division/country:us/state:tx/cd:36',
#      'office': '2236 Rayburn House Office Building',
#      'phone': '202-225-1555',
#      'fax': None,
#      'state': 'TX',
#      'district': '36',
#      'at_large': False,
#      'geoid': '4836',
#      'missed_votes_pct': 3.55,
#      'votes_with_party_pct': 91.15,
#      'votes_against_party_pct': 8.72},
#     {'id': 'B001298',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001298.json',
#      'first_name': 'Don',
#      'middle_name': None,
#      'last_name': 'Bacon',
#      'suffix': None,
#      'date_of_birth': '1963-08-16',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'repdonbacon',
#      'facebook_account': 'RepDonBacon',
#      'youtube_account': None,
#      'govtrack_id': '412713',
#      'cspan_id': '103442',
#      'votesmart_id': '166299',
#      'icpsr_id': '21701',
#      'crp_id': 'N00037049',
#      'google_entity_id': '/m/01311t71',
#      'fec_candidate_id': 'H6NE02125',
#      'url': 'https://bacon.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+4',
#      'dw_nominate': 0.41,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 1,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:02:14 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ne/cd:2',
#      'office': '1024 Longworth House Office Building',
#      'phone': '202-225-4155',
#      'fax': None,
#      'state': 'NE',
#      'district': '2',
#      'at_large': False,
#      'geoid': '3102',
#      'missed_votes_pct': 0.12,
#      'votes_with_party_pct': 88.0,
#      'votes_against_party_pct': 11.88},
#     {'id': 'B001307',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001307.json',
#      'first_name': 'James',
#      'middle_name': None,
#      'last_name': 'Baird',
#      'suffix': None,
#      'date_of_birth': '1945-06-04',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepJimBaird',
#      'facebook_account': None,
#      'youtube_account': None,
#      'govtrack_id': '412777',
#      'cspan_id': None,
#      'votesmart_id': '86013',
#      'icpsr_id': None,
#      'crp_id': 'N00041954',
#      'google_entity_id': '/g/11gfd5wndr',
#      'fec_candidate_id': 'H8IN04199',
#      'url': 'https://baird.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+17',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '2',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 7,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:21 -0400',
#      'ocd_id': 'ocd-division/country:us/state:in/cd:4',
#      'office': '532 Cannon House Office Building',
#      'phone': '202-225-5037',
#      'fax': None,
#      'state': 'IN',
#      'district': '4',
#      'at_large': False,
#      'geoid': '1804',
#      'missed_votes_pct': 0.86,
#      'votes_with_party_pct': 95.76,
#      'votes_against_party_pct': 4.11},
#     {'id': 'B001306',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001306.json',
#      'first_name': 'Troy',
#      'middle_name': None,
#      'last_name': 'Balderson',
#      'suffix': None,
#      'date_of_birth': '1962-01-16',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepBalderson',
#      'facebook_account': None,
#      'youtube_account': None,
#      'govtrack_id': '412747',
#      'cspan_id': None,
#      'votesmart_id': '102781',
#      'icpsr_id': None,
#      'crp_id': 'N00042194',
#      'google_entity_id': '/m/09ry4tm',
#      'fec_candidate_id': 'H8OH12180',
#      'url': 'https://balderson.house.gov',
#      'rss_url': '',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+7',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 1,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:02:56 -0400',
#      'ocd_id': 'ocd-division/country:us/state:oh/cd:12',
#      'office': '1221 Longworth House Office Building',
#      'phone': '202-225-5355',
#      'fax': None,
#      'state': 'OH',
#      'district': '12',
#      'at_large': False,
#      'geoid': '3912',
#      'missed_votes_pct': 0.12,
#      'votes_with_party_pct': 97.03,
#      'votes_against_party_pct': 2.85},
#     {'id': 'B001299',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001299.json',
#      'first_name': 'Jim',
#      'middle_name': None,
#      'last_name': 'Banks',
#      'suffix': None,
#      'date_of_birth': '1979-07-16',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepJimBanks',
#      'facebook_account': 'RepJimBanks',
#      'youtube_account': None,
#      'govtrack_id': '412702',
#      'cspan_id': '89806',
#      'votesmart_id': '116801',
#      'icpsr_id': '21702',
#      'crp_id': 'N00037185',
#      'google_entity_id': '/m/0j621nj',
#      'fec_candidate_id': 'H6IN03229',
#      'url': 'https://banks.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+18',
#      'dw_nominate': 0.633,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 0,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:02:30 -0400',
#      'ocd_id': 'ocd-division/country:us/state:in/cd:3',
#      'office': '1713 Longworth House Office Building',
#      'phone': '202-225-4436',
#      'fax': None,
#      'state': 'IN',
#      'district': '3',
#      'at_large': False,
#      'geoid': '1803',
#      'missed_votes_pct': 0.0,
#      'votes_with_party_pct': 93.33,
#      'votes_against_party_pct': 6.55},
#     {'id': 'B001282',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001282.json',
#      'first_name': 'Andy',
#      'middle_name': None,
#      'last_name': 'Barr',
#      'suffix': None,
#      'date_of_birth': '1973-07-24',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepAndyBarr',
#      'facebook_account': 'RepAndyBarr',
#      'youtube_account': 'RepAndyBarr',
#      'govtrack_id': '412541',
#      'cspan_id': '61848',
#      'votesmart_id': '117290',
#      'icpsr_id': '21333',
#      'crp_id': 'N00031233',
#      'google_entity_id': '/m/0ddc6r6',
#      'fec_candidate_id': 'H0KY06104',
#      'url': 'https://barr.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+9',
#      'dw_nominate': 0.492,
#      'ideal_point': None,
#      'seniority': '8',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 9,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:11 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ky/cd:6',
#      'office': '2430 Rayburn House Office Building',
#      'phone': '202-225-4706',
#      'fax': None,
#      'state': 'KY',
#      'district': '6',
#      'at_large': False,
#      'geoid': '2106',
#      'missed_votes_pct': 1.1,
#      'votes_with_party_pct': 94.63,
#      'votes_against_party_pct': 5.25},
#     {'id': 'B001300',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001300.json',
#      'first_name': 'Nanette',
#      'middle_name': None,
#      'last_name': 'Barragán',
#      'suffix': None,
#      'date_of_birth': '1976-09-15',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepBarragan',
#      'facebook_account': 'CongresswomanBarragan',
#      'youtube_account': None,
#      'govtrack_id': '412687',
#      'cspan_id': '104730',
#      'votesmart_id': '166270',
#      'icpsr_id': '21703',
#      'crp_id': 'N00037019',
#      'google_entity_id': '/g/11bx55ybbz',
#      'fec_candidate_id': 'H6CA44103',
#      'url': 'https://barragan.house.gov',
#      'rss_url': 'https://barragan.house.gov/feed/',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+35',
#      'dw_nominate': -0.51,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 16,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:59 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ca/cd:44',
#      'office': '1030 Longworth House Office Building',
#      'phone': '202-225-8220',
#      'fax': None,
#      'state': 'CA',
#      'district': '44',
#      'at_large': False,
#      'geoid': '0644',
#      'missed_votes_pct': 1.96,
#      'votes_with_party_pct': 98.37,
#      'votes_against_party_pct': 1.5},
#     {'id': 'B001270',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001270.json',
#      'first_name': 'Karen',
#      'middle_name': None,
#      'last_name': 'Bass',
#      'suffix': None,
#      'date_of_birth': '1953-10-03',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepKarenBass',
#      'facebook_account': 'RepKarenBass',
#      'youtube_account': 'RepKarenBass',
#      'govtrack_id': '412404',
#      'cspan_id': '62502',
#      'votesmart_id': '28963',
#      'icpsr_id': '21110',
#      'crp_id': 'N00031877',
#      'google_entity_id': '/m/027g9m6',
#      'fec_candidate_id': 'H0CA33117',
#      'url': 'https://bass.house.gov',
#      'rss_url': 'https://bass.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+37',
#      'dw_nominate': -0.585,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 50,
#      'total_present': 1,
#      'last_updated': '2020-06-02 18:30:33 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ca/cd:37',
#      'office': '2059 Rayburn House Office Building',
#      'phone': '202-225-7084',
#      'fax': None,
#      'state': 'CA',
#      'district': '37',
#      'at_large': False,
#      'geoid': '0637',
#      'missed_votes_pct': 6.13,
#      'votes_with_party_pct': 98.04,
#      'votes_against_party_pct': 1.83},
#     {'id': 'B001281',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001281.json',
#      'first_name': 'Joyce',
#      'middle_name': None,
#      'last_name': 'Beatty',
#      'suffix': None,
#      'date_of_birth': '1950-03-12',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepBeatty',
#      'facebook_account': 'RepJoyceBeatty',
#      'youtube_account': None,
#      'govtrack_id': '412565',
#      'cspan_id': '67294',
#      'votesmart_id': '2427',
#      'icpsr_id': '21352',
#      'crp_id': 'N00033904',
#      'google_entity_id': '/m/03lcwb',
#      'fec_candidate_id': 'H2OH03125',
#      'url': 'https://beatty.house.gov',
#      'rss_url': 'https://beatty.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+19',
#      'dw_nominate': -0.429,
#      'ideal_point': None,
#      'seniority': '8',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 41,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:36 -0400',
#      'ocd_id': 'ocd-division/country:us/state:oh/cd:3',
#      'office': '2303 Rayburn House Office Building',
#      'phone': '202-225-4324',
#      'fax': None,
#      'state': 'OH',
#      'district': '3',
#      'at_large': False,
#      'geoid': '3903',
#      'missed_votes_pct': 5.02,
#      'votes_with_party_pct': 99.22,
#      'votes_against_party_pct': 0.65},
#     {'id': 'B001287',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001287.json',
#      'first_name': 'Ami',
#      'middle_name': None,
#      'last_name': 'Bera',
#      'suffix': None,
#      'date_of_birth': '1965-03-02',
#      'gender': 'M',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepBera',
#      'facebook_account': 'RepAmiBera',
#      'youtube_account': 'repamibera',
#      'govtrack_id': '412512',
#      'cspan_id': '1033636',
#      'votesmart_id': '120030',
#      'icpsr_id': '21304',
#      'crp_id': 'N00030717',
#      'google_entity_id': '/m/0dgqnts',
#      'fec_candidate_id': 'H0CA03078',
#      'url': 'https://bera.house.gov',
#      'rss_url': 'https://bera.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+3',
#      'dw_nominate': -0.232,
#      'ideal_point': None,
#      'seniority': '8',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 3,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:03:09 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ca/cd:7',
#      'office': '1727 Longworth House Office Building',
#      'phone': '202-225-5716',
#      'fax': None,
#      'state': 'CA',
#      'district': '7',
#      'at_large': False,
#      'geoid': '0607',
#      'missed_votes_pct': 0.37,
#      'votes_with_party_pct': 98.15,
#      'votes_against_party_pct': 1.73},
#     {'id': 'B001301',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001301.json',
#      'first_name': 'Jack',
#      'middle_name': None,
#      'last_name': 'Bergman',
#      'suffix': None,
#      'date_of_birth': '1947-02-02',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepJackBergman',
#      'facebook_account': 'RepJackBergman',
#      'youtube_account': 'RepJackBergman',
#      'govtrack_id': '412709',
#      'cspan_id': '1020529',
#      'votesmart_id': '170172',
#      'icpsr_id': '21704',
#      'crp_id': 'N00039533',
#      'google_entity_id': '/m/05b2l3v',
#      'fec_candidate_id': 'H6MI01226',
#      'url': 'https://bergman.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+9',
#      'dw_nominate': 0.425,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 14,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:05 -0400',
#      'ocd_id': 'ocd-division/country:us/state:mi/cd:1',
#      'office': '414 Cannon House Office Building',
#      'phone': '202-225-4735',
#      'fax': None,
#      'state': 'MI',
#      'district': '1',
#      'at_large': False,
#      'geoid': '2601',
#      'missed_votes_pct': 1.72,
#      'votes_with_party_pct': 92.58,
#      'votes_against_party_pct': 7.3},
#     {'id': 'B001292',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001292.json',
#      'first_name': 'Donald',
#      'middle_name': None,
#      'last_name': 'Beyer',
#      'suffix': None,
#      'date_of_birth': '1950-06-20',
#      'gender': 'M',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepDonBeyer',
#      'facebook_account': 'RepDonBeyer',
#      'youtube_account': None,
#      'govtrack_id': '412657',
#      'cspan_id': '21141',
#      'votesmart_id': '1707',
#      'icpsr_id': '21554',
#      'crp_id': 'N00036018',
#      'google_entity_id': '/m/053g16',
#      'fec_candidate_id': 'H4VA08224',
#      'url': 'https://beyer.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+6',
#      'dw_nominate': -0.386,
#      'ideal_point': None,
#      'seniority': '6',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 26,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:48 -0400',
#      'ocd_id': 'ocd-division/country:us/state:va/cd:8',
#      'office': '1119 Longworth House Office Building',
#      'phone': '202-225-4376',
#      'fax': None,
#      'state': 'VA',
#      'district': '8',
#      'at_large': False,
#      'geoid': '5108',
#      'missed_votes_pct': 3.19,
#      'votes_with_party_pct': 98.98,
#      'votes_against_party_pct': 0.89},
#     {'id': 'B001302',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001302.json',
#      'first_name': 'Andy',
#      'middle_name': None,
#      'last_name': 'Biggs',
#      'suffix': None,
#      'date_of_birth': '1958-11-07',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepAndyBiggsAZ',
#      'facebook_account': 'RepAndyBiggs',
#      'youtube_account': None,
#      'govtrack_id': '412683',
#      'cspan_id': '105145',
#      'votesmart_id': '28088',
#      'icpsr_id': '21705',
#      'crp_id': 'N00039293',
#      'google_entity_id': '/m/0_1m23v',
#      'fec_candidate_id': 'H6AZ05083',
#      'url': 'https://biggs.house.gov',
#      'rss_url': 'https://biggs.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+15',
#      'dw_nominate': 0.882,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 19,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:54 -0400',
#      'ocd_id': 'ocd-division/country:us/state:az/cd:5',
#      'office': '1318 Longworth House Office Building',
#      'phone': '202-225-2635',
#      'fax': None,
#      'state': 'AZ',
#      'district': '5',
#      'at_large': False,
#      'geoid': '0405',
#      'missed_votes_pct': 2.33,
#      'votes_with_party_pct': 78.99,
#      'votes_against_party_pct': 20.89},
#     {'id': 'B001257',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001257.json',
#      'first_name': 'Gus',
#      'middle_name': None,
#      'last_name': 'Bilirakis',
#      'suffix': None,
#      'date_of_birth': '1963-02-08',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepGusBilirakis',
#      'facebook_account': 'GusBilirakis',
#      'youtube_account': 'RepGusBilirakis',
#      'govtrack_id': '412250',
#      'cspan_id': '1022873',
#      'votesmart_id': '17318',
#      'icpsr_id': '20758',
#      'crp_id': 'N00027462',
#      'google_entity_id': '/m/0dy3z1',
#      'fec_candidate_id': 'H6FL09070',
#      'url': 'https://bilirakis.house.gov',
#      'rss_url': 'https://bilirakis.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+8',
#      'dw_nominate': 0.404,
#      'ideal_point': None,
#      'seniority': '16',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 30,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:43 -0400',
#      'ocd_id': 'ocd-division/country:us/state:fl/cd:12',
#      'office': '2227 Rayburn House Office Building',
#      'phone': '202-225-5755',
#      'fax': None,
#      'state': 'FL',
#      'district': '12',
#      'at_large': False,
#      'geoid': '1212',
#      'missed_votes_pct': 3.68,
#      'votes_with_party_pct': 92.57,
#      'votes_against_party_pct': 7.3},
#     {'id': 'B001250',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001250.json',
#      'first_name': 'Rob',
#      'middle_name': None,
#      'last_name': 'Bishop',
#      'suffix': None,
#      'date_of_birth': '1951-07-13',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': '',
#      'twitter_account': 'RepRobBishop',
#      'facebook_account': 'RepRobBishop',
#      'youtube_account': 'CongressmanBishop',
#      'govtrack_id': '400029',
#      'cspan_id': '1003621',
#      'votesmart_id': '50544',
#      'icpsr_id': '20357',
#      'crp_id': 'N00025292',
#      'google_entity_id': '/m/02tn41',
#      'fec_candidate_id': 'H2UT01094',
#      'url': 'https://robbishop.house.gov',
#      'rss_url': 'https://robbishop.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+26',
#      'dw_nominate': 0.536,
#      'ideal_point': None,
#      'seniority': '18',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 46,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:36 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ut/cd:1',
#      'office': '123 Cannon House Office Building',
#      'phone': '202-225-0453',
#      'fax': None,
#      'state': 'UT',
#      'district': '1',
#      'at_large': False,
#      'geoid': '4901',
#      'missed_votes_pct': 5.64,
#      'votes_with_party_pct': 91.76,
#      'votes_against_party_pct': 8.1},
#     {'id': 'B001311',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001311.json',
#      'first_name': 'Dan',
#      'middle_name': None,
#      'last_name': 'Bishop',
#      'suffix': None,
#      'date_of_birth': '1964-07-01',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepDanBishop',
#      'facebook_account': None,
#      'youtube_account': None,
#      'govtrack_id': '412844',
#      'cspan_id': None,
#      'votesmart_id': None,
#      'icpsr_id': None,
#      'crp_id': 'N00044335',
#      'google_entity_id': '/m/013bg9xz',
#      'fec_candidate_id': 'H0NC09187',
#      'url': 'https://danbishop.house.gov/',
#      'rss_url': '',
#      'contact_form': 'https://danbishop.house.gov/contact/email',
#      'in_office': True,
#      'cook_pvi': 'R+8',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '2',
#      'next_election': '2020',
#      'total_votes': 285,
#      'missed_votes': 33,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:41 -0400',
#      'ocd_id': 'ocd-division/country:us/state:nc/cd:9',
#      'office': '132 Cannon House Office Building',
#      'phone': '202-225-1976',
#      'fax': None,
#      'state': 'NC',
#      'district': '9',
#      'at_large': False,
#      'geoid': '3709',
#      'missed_votes_pct': 11.58,
#      'votes_with_party_pct': 93.57,
#      'votes_against_party_pct': 6.43},
#     {'id': 'B000490',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B000490.json',
#      'first_name': 'Sanford',
#      'middle_name': 'D.',
#      'last_name': 'Bishop',
#      'suffix': 'Jr.',
#      'date_of_birth': '1947-02-04',
#      'gender': 'M',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'SanfordBishop',
#      'facebook_account': 'sanfordbishop',
#      'youtube_account': 'RepSanfordBishop',
#      'govtrack_id': '400030',
#      'cspan_id': '26194',
#      'votesmart_id': '26817',
#      'icpsr_id': '29339',
#      'crp_id': 'N00002674',
#      'google_entity_id': '/m/02554k',
#      'fec_candidate_id': 'H2GA02031',
#      'url': 'https://bishop.house.gov',
#      'rss_url': 'https://bishop.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+6',
#      'dw_nominate': -0.282,
#      'ideal_point': None,
#      'seniority': '28',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 28,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:44 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ga/cd:2',
#      'office': '2407 Rayburn House Office Building',
#      'phone': '202-225-3631',
#      'fax': None,
#      'state': 'GA',
#      'district': '2',
#      'at_large': False,
#      'geoid': '1302',
#      'missed_votes_pct': 3.43,
#      'votes_with_party_pct': 98.73,
#      'votes_against_party_pct': 1.15},
#     {'id': 'B000574',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B000574.json',
#      'first_name': 'Earl',
#      'middle_name': None,
#      'last_name': 'Blumenauer',
#      'suffix': None,
#      'date_of_birth': '1948-08-16',
#      'gender': 'M',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'BlumenauerMedia',
#      'facebook_account': None,
#      'youtube_account': 'RepBlumenauer',
#      'govtrack_id': '400033',
#      'cspan_id': '43809',
#      'votesmart_id': '367',
#      'icpsr_id': '29588',
#      'crp_id': 'N00007727',
#      'google_entity_id': '/m/033tw8',
#      'fec_candidate_id': 'H6OR03064',
#      'url': 'https://blumenauer.house.gov',
#      'rss_url': 'https://blumenauer.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+24',
#      'dw_nominate': -0.427,
#      'ideal_point': None,
#      'seniority': '26',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 10,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:10 -0400',
#      'ocd_id': 'ocd-division/country:us/state:or/cd:3',
#      'office': '1111 Longworth House Office Building',
#      'phone': '202-225-4811',
#      'fax': None,
#      'state': 'OR',
#      'district': '3',
#      'at_large': False,
#      'geoid': '4103',
#      'missed_votes_pct': 1.23,
#      'votes_with_party_pct': 97.51,
#      'votes_against_party_pct': 2.36},
#     {'id': 'B001303',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001303.json',
#      'first_name': 'Lisa',
#      'middle_name': None,
#      'last_name': 'Blunt Rochester',
#      'suffix': None,
#      'date_of_birth': '1962-02-10',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepLBR',
#      'facebook_account': 'Rep.BluntRochester',
#      'youtube_account': None,
#      'govtrack_id': '412689',
#      'cspan_id': '104772',
#      'votesmart_id': '173249',
#      'icpsr_id': '21706',
#      'crp_id': 'N00038414',
#      'google_entity_id': '/g/11c328y56v',
#      'fec_candidate_id': 'H6DE00206',
#      'url': 'https://bluntrochester.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+6',
#      'dw_nominate': -0.329,
#      'ideal_point': None,
#      'seniority': '4',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 5,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:03:36 -0400',
#      'ocd_id': 'ocd-division/country:us/state:de/cd:1',
#      'office': '1519 Longworth House Office Building',
#      'phone': '202-225-4165',
#      'fax': None,
#      'state': 'DE',
#      'district': 'At-Large',
#      'at_large': True,
#      'geoid': '1000',
#      'missed_votes_pct': 0.61,
#      'votes_with_party_pct': 99.38,
#      'votes_against_party_pct': 0.49},
#     {'id': 'B001278',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001278.json',
#      'first_name': 'Suzanne',
#      'middle_name': None,
#      'last_name': 'Bonamici',
#      'suffix': None,
#      'date_of_birth': '1954-10-14',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepBonamici',
#      'facebook_account': 'congresswomanbonamici',
#      'youtube_account': 'RepSuzanneBonamici',
#      'govtrack_id': '412501',
#      'cspan_id': '63966',
#      'votesmart_id': '59641',
#      'icpsr_id': '21198',
#      'crp_id': 'N00033474',
#      'google_entity_id': '/m/02q453x',
#      'fec_candidate_id': 'H2OR01133',
#      'url': 'https://bonamici.house.gov',
#      'rss_url': 'https://bonamici.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+9',
#      'dw_nominate': -0.393,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 4,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:03:17 -0400',
#      'ocd_id': 'ocd-division/country:us/state:or/cd:1',
#      'office': '2231 Rayburn House Office Building',
#      'phone': '202-225-0855',
#      'fax': None,
#      'state': 'OR',
#      'district': '1',
#      'at_large': False,
#      'geoid': '4101',
#      'missed_votes_pct': 0.49,
#      'votes_with_party_pct': 98.52,
#      'votes_against_party_pct': 1.36},
#     {'id': 'B001295',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001295.json',
#      'first_name': 'Mike',
#      'middle_name': None,
#      'last_name': 'Bost',
#      'suffix': None,
#      'date_of_birth': '1960-12-30',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepBost',
#      'facebook_account': 'RepBost',
#      'youtube_account': None,
#      'govtrack_id': '412629',
#      'cspan_id': '76176',
#      'votesmart_id': '6302',
#      'icpsr_id': '21519',
#      'crp_id': 'N00035420',
#      'google_entity_id': '/m/0kry42',
#      'fec_candidate_id': 'H4IL12060',
#      'url': 'https://bost.house.gov',
#      'rss_url': 'https://bost.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+5',
#      'dw_nominate': 0.27,
#      'ideal_point': None,
#      'seniority': '6',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 92,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:27 -0400',
#      'ocd_id': 'ocd-division/country:us/state:il/cd:12',
#      'office': '1440 Longworth House Office Building',
#      'phone': '202-225-5661',
#      'fax': None,
#      'state': 'IL',
#      'district': '12',
#      'at_large': False,
#      'geoid': '1712',
#      'missed_votes_pct': 11.27,
#      'votes_with_party_pct': 92.2,
#      'votes_against_party_pct': 7.66},
#     {'id': 'B001296',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/B001296.json',
#      'first_name': 'Brendan',
#      'middle_name': None,
#      'last_name': 'Boyle',
#      'suffix': None,
#      'date_of_birth': '1977-02-06',
#      'gender': 'M',
# ...
#      'votes_against_party_pct': 3.98},
#     {'id': 'W000816',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/W000816.json',
#      'first_name': 'Roger',
#      'middle_name': None,
#      'last_name': 'Williams',
#      'suffix': None,
#      'date_of_birth': '1949-09-13',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepRWilliams',
#      'facebook_account': 'RepRogerWilliams',
#      'youtube_account': None,
#      'govtrack_id': '412578',
#      'cspan_id': '623742',
#      'votesmart_id': '50112',
#      'icpsr_id': '21364',
#      'crp_id': 'N00030602',
#      'google_entity_id': '/m/08rszb',
#      'fec_candidate_id': 'H2TX33040',
#      'url': 'https://williams.house.gov',
#      'rss_url': 'https://williams.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+11',
#      'dw_nominate': 0.587,
#      'ideal_point': None,
#      'seniority': '8',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 24,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:50 -0400',
#      'ocd_id': 'ocd-division/country:us/state:tx/cd:25',
#      'office': '1708 Longworth House Office Building',
#      'phone': '202-225-9896',
#      'fax': None,
#      'state': 'TX',
#      'district': '25',
#      'at_large': False,
#      'geoid': '4825',
#      'missed_votes_pct': 2.94,
#      'votes_with_party_pct': 95.29,
#      'votes_against_party_pct': 4.58},
#     {'id': 'W000795',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/W000795.json',
#      'first_name': 'Joe',
#      'middle_name': None,
#      'last_name': 'Wilson',
#      'suffix': None,
#      'date_of_birth': '1947-07-31',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepJoeWilson',
#      'facebook_account': 'JoeWilson',
#      'youtube_account': 'RepJoeWilson',
#      'govtrack_id': '400433',
#      'cspan_id': '1002567',
#      'votesmart_id': '3985',
#      'icpsr_id': '20138',
#      'crp_id': 'N00024809',
#      'google_entity_id': '/m/03tll0',
#      'fec_candidate_id': 'H2SC02059',
#      'url': 'https://joewilson.house.gov',
#      'rss_url': 'https://joewilson.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+12',
#      'dw_nominate': 0.538,
#      'ideal_point': None,
#      'seniority': '20',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 27,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:46 -0400',
#      'ocd_id': 'ocd-division/country:us/state:sc/cd:2',
#      'office': '1436 Longworth House Office Building',
#      'phone': '202-225-2452',
#      'fax': None,
#      'state': 'SC',
#      'district': '2',
#      'at_large': False,
#      'geoid': '4502',
#      'missed_votes_pct': 3.31,
#      'votes_with_party_pct': 94.63,
#      'votes_against_party_pct': 5.24},
#     {'id': 'W000808',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/W000808.json',
#      'first_name': 'Frederica',
#      'middle_name': None,
#      'last_name': 'Wilson',
#      'suffix': None,
#      'date_of_birth': '1942-11-05',
#      'gender': 'F',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepWilson',
#      'facebook_account': 'RepWilson',
#      'youtube_account': 'repfredericawilson',
#      'govtrack_id': '412412',
#      'cspan_id': '87016',
#      'votesmart_id': '17319',
#      'icpsr_id': '21118',
#      'crp_id': 'N00030650',
#      'google_entity_id': '/m/03cg3tv',
#      'fec_candidate_id': 'H0FL17068',
#      'url': 'https://wilson.house.gov',
#      'rss_url': 'https://wilson.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+34',
#      'dw_nominate': -0.476,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 118,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:25 -0400',
#      'ocd_id': 'ocd-division/country:us/state:fl/cd:24',
#      'office': '2445 Rayburn House Office Building',
#      'phone': '202-225-4506',
#      'fax': None,
#      'state': 'FL',
#      'district': '24',
#      'at_large': False,
#      'geoid': '1224',
#      'missed_votes_pct': 14.46,
#      'votes_with_party_pct': 99.0,
#      'votes_against_party_pct': 0.86},
#     {'id': 'W000804',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#      'first_name': 'Robert',
#      'middle_name': 'J.',
#      'last_name': 'Wittman',
#      'suffix': None,
#      'date_of_birth': '1959-02-03',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RobWittman',
#      'facebook_account': 'RepRobWittman',
#      'youtube_account': 'RobWittman',
#      'govtrack_id': '412255',
#      'cspan_id': '1028089',
#      'votesmart_id': '58133',
#      'icpsr_id': '20756',
#      'crp_id': 'N00029459',
#      'google_entity_id': '/m/03cx7ld',
#      'fec_candidate_id': 'H8VA01147',
#      'url': 'https://wittman.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+15',
#      'dw_nominate': 0.444,
#      'ideal_point': None,
#      'seniority': '14',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 7,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:20 -0400',
#      'ocd_id': 'ocd-division/country:us/state:va/cd:1',
#      'office': '2055 Rayburn House Office Building',
#      'phone': '202-225-4261',
#      'fax': None,
#      'state': 'VA',
#      'district': '1',
#      'at_large': False,
#      'geoid': '5101',
#      'missed_votes_pct': 0.86,
#      'votes_with_party_pct': 95.64,
#      'votes_against_party_pct': 4.23},
#     {'id': 'W000809',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/W000809.json',
#      'first_name': 'Steve',
#      'middle_name': None,
#      'last_name': 'Womack',
#      'suffix': None,
#      'date_of_birth': '1957-02-18',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'Rep_SteveWomack',
#      'facebook_account': 'RepSteveWomack',
#      'youtube_account': 'CongressmanWomack',
#      'govtrack_id': '412402',
#      'cspan_id': '1033625',
#      'votesmart_id': '71815',
#      'icpsr_id': '21108',
#      'crp_id': 'N00031857',
#      'google_entity_id': '/m/0cmcvkz',
#      'fec_candidate_id': 'H0AR03055',
#      'url': 'https://womack.house.gov',
#      'rss_url': 'https://womack.house.gov/news/rss.aspx',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+19',
#      'dw_nominate': 0.354,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 0,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:02:44 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ar/cd:3',
#      'office': '2412 Rayburn House Office Building',
#      'phone': '202-225-4301',
#      'fax': None,
#      'state': 'AR',
#      'district': '3',
#      'at_large': False,
#      'geoid': '0503',
#      'missed_votes_pct': 0.0,
#      'votes_with_party_pct': 95.43,
#      'votes_against_party_pct': 4.45},
#     {'id': 'W000810',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/W000810.json',
#      'first_name': 'Rob',
#      'middle_name': None,
#      'last_name': 'Woodall',
#      'suffix': None,
#      'date_of_birth': '1970-02-11',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': '',
#      'twitter_account': 'RepRobWoodall',
#      'facebook_account': 'RepRobWoodall',
#      'youtube_account': 'RobWoodallGA07',
#      'govtrack_id': '412416',
#      'cspan_id': '623342',
#      'votesmart_id': '122251',
#      'icpsr_id': '21122',
#      'crp_id': 'N00032416',
#      'google_entity_id': '/m/0cz8ryh',
#      'fec_candidate_id': 'H0GA07133',
#      'url': 'https://woodall.house.gov',
#      'rss_url': 'https://woodall.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+9',
#      'dw_nominate': 0.598,
#      'ideal_point': None,
#      'seniority': '10',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 12,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:08 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ga/cd:7',
#      'office': '1724 Longworth House Office Building',
#      'phone': '202-225-4272',
#      'fax': None,
#      'state': 'GA',
#      'district': '7',
#      'at_large': False,
#      'geoid': '1307',
#      'missed_votes_pct': 1.47,
#      'votes_with_party_pct': 94.11,
#      'votes_against_party_pct': 5.76},
#     {'id': 'W000827',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/W000827.json',
#      'first_name': 'Ron',
#      'middle_name': None,
#      'last_name': 'Wright',
#      'suffix': None,
#      'date_of_birth': '1953-04-08',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepRonWright',
#      'facebook_account': None,
#      'youtube_account': None,
#      'govtrack_id': '412823',
#      'cspan_id': None,
#      'votesmart_id': None,
#      'icpsr_id': None,
#      'crp_id': 'N00042240',
#      'google_entity_id': '/g/11fgkl82tl',
#      'fec_candidate_id': 'H8TX06233',
#      'url': 'https://wright.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+9',
#      'dw_nominate': None,
#      'ideal_point': None,
#      'seniority': '2',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 162,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:25 -0400',
#      'ocd_id': 'ocd-division/country:us/state:tx/cd:6',
#      'office': '428 Cannon House Office Building',
#      'phone': '202-225-2002',
#      'fax': None,
#      'state': 'TX',
#      'district': '6',
#      'at_large': False,
#      'geoid': '4806',
#      'missed_votes_pct': 19.85,
#      'votes_with_party_pct': 92.91,
#      'votes_against_party_pct': 6.93},
#     {'id': 'Y000062',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/Y000062.json',
#      'first_name': 'John',
#      'middle_name': None,
#      'last_name': 'Yarmuth',
#      'suffix': None,
#      'date_of_birth': '1947-11-04',
#      'gender': 'M',
#      'party': 'D',
#      'leadership_role': None,
#      'twitter_account': 'RepJohnYarmuth',
#      'facebook_account': '214258646163',
#      'youtube_account': 'RepJohnYarmuth',
#      'govtrack_id': '412211',
#      'cspan_id': '1021662',
#      'votesmart_id': '58579',
#      'icpsr_id': '20723',
#      'crp_id': 'N00028073',
#      'google_entity_id': '/m/0bb00g',
#      'fec_candidate_id': 'H6KY03124',
#      'url': 'https://yarmuth.house.gov',
#      'rss_url': None,
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'D+6',
#      'dw_nominate': -0.378,
#      'ideal_point': None,
#      'seniority': '14',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 17,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:57 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ky/cd:3',
#      'office': '402 Cannon House Office Building',
#      'phone': '202-225-5401',
#      'fax': None,
#      'state': 'KY',
#      'district': '3',
#      'at_large': False,
#      'geoid': '2103',
#      'missed_votes_pct': 2.08,
#      'votes_with_party_pct': 98.87,
#      'votes_against_party_pct': 1.0},
#     {'id': 'Y000065',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/Y000065.json',
#      'first_name': 'Ted',
#      'middle_name': None,
#      'last_name': 'Yoho',
#      'suffix': None,
#      'date_of_birth': '1955-04-13',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': '',
#      'twitter_account': 'RepTedYoho',
#      'facebook_account': 'CongressmanTedYoho',
#      'youtube_account': 'RepTedYoho',
#      'govtrack_id': '412525',
#      'cspan_id': '63943',
#      'votesmart_id': '137622',
#      'icpsr_id': '21317',
#      'crp_id': 'N00033220',
#      'google_entity_id': '/m/0l8lwvh',
#      'fec_candidate_id': 'H2FL06109',
#      'url': 'https://yoho.house.gov',
#      'rss_url': 'https://yoho.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+9',
#      'dw_nominate': 0.704,
#      'ideal_point': None,
#      'seniority': '8',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 69,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:30 -0400',
#      'ocd_id': 'ocd-division/country:us/state:fl/cd:3',
#      'office': '1730 Longworth House Office Building',
#      'phone': '202-225-5744',
#      'fax': None,
#      'state': 'FL',
#      'district': '3',
#      'at_large': False,
#      'geoid': '1203',
#      'missed_votes_pct': 8.46,
#      'votes_with_party_pct': 87.06,
#      'votes_against_party_pct': 12.8},
#     {'id': 'Y000033',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/Y000033.json',
#      'first_name': 'Don',
#      'middle_name': None,
#      'last_name': 'Young',
#      'suffix': None,
#      'date_of_birth': '1933-06-09',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepDonYoung',
#      'facebook_account': 'RepDonYoung',
#      'youtube_account': 'RepDonYoung',
#      'govtrack_id': '400440',
#      'cspan_id': '1897',
#      'votesmart_id': '26717',
#      'icpsr_id': '14066',
#      'crp_id': 'N00007999',
#      'google_entity_id': '/m/024p1k',
#      'fec_candidate_id': 'H6AK00045',
#      'url': 'https://donyoung.house.gov',
#      'rss_url': 'https://donyoung.house.gov/news/rss.aspx',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+9',
#      'dw_nominate': 0.284,
#      'ideal_point': None,
#      'seniority': '48',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 36,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:30:39 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ak/cd:1',
#      'office': '2314 Rayburn House Office Building',
#      'phone': '202-225-5765',
#      'fax': None,
#      'state': 'AK',
#      'district': 'At-Large',
#      'at_large': True,
#      'geoid': '0200',
#      'missed_votes_pct': 4.41,
#      'votes_with_party_pct': 87.98,
#      'votes_against_party_pct': 11.89},
#     {'id': 'Z000017',
#      'title': 'Representative',
#      'short_title': 'Rep.',
#      'api_uri': 'https://api.propublica.org/congress/v1/members/Z000017.json',
#      'first_name': 'Lee',
#      'middle_name': None,
#      'last_name': 'Zeldin',
#      'suffix': None,
#      'date_of_birth': '1980-01-30',
#      'gender': 'M',
#      'party': 'R',
#      'leadership_role': None,
#      'twitter_account': 'RepLeeZeldin',
#      'facebook_account': 'RepLeeZeldin',
#      'youtube_account': None,
#      'govtrack_id': '412646',
#      'cspan_id': '61616',
#      'votesmart_id': '110252',
#      'icpsr_id': '21539',
#      'crp_id': 'N00029404',
#      'google_entity_id': '/m/03h4jcq',
#      'fec_candidate_id': 'H8NY01148',
#      'url': 'https://zeldin.house.gov',
#      'rss_url': 'https://zeldin.house.gov/rss.xml',
#      'contact_form': None,
#      'in_office': True,
#      'cook_pvi': 'R+5',
#      'dw_nominate': 0.387,
#      'ideal_point': None,
#      'seniority': '6',
#      'next_election': '2020',
#      'total_votes': 816,
#      'missed_votes': 8,
#      'total_present': 0,
#      'last_updated': '2020-06-02 18:31:17 -0400',
#      'ocd_id': 'ocd-division/country:us/state:ny/cd:1',
#      'office': '2441 Rayburn House Office Building',
#      'phone': '202-225-3826',
#      'fax': None,
#      'state': 'NY',
#      'district': '1',
#      'at_large': False,
#      'geoid': '3601',
#      'missed_votes_pct': 0.98,
#      'votes_with_party_pct': 89.26,
#      'votes_against_party_pct': 10.61}]}]}

# %%
congress_members = members_json['results'][0]["members"]
congress_members
# Out:
# [{'id': 'A000374',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000374.json',
#   'first_name': 'Ralph',
#   'middle_name': None,
#   'last_name': 'Abraham',
#   'suffix': None,
#   'date_of_birth': '1954-09-16',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': '',
#   'twitter_account': 'RepAbraham',
#   'facebook_account': 'CongressmanRalphAbraham',
#   'youtube_account': None,
#   'govtrack_id': '412630',
#   'cspan_id': '76236',
#   'votesmart_id': '155414',
#   'icpsr_id': '21522',
#   'crp_id': 'N00036633',
#   'google_entity_id': '/m/012dwd7_',
#   'fec_candidate_id': 'H4LA05221',
#   'url': 'https://abraham.house.gov',
#   'rss_url': 'https://abraham.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+15',
#   'dw_nominate': 0.54,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 264,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:22 -0400',
#   'ocd_id': 'ocd-division/country:us/state:la/cd:5',
#   'office': '417 Cannon House Office Building',
#   'phone': '202-225-8490',
#   'fax': None,
#   'state': 'LA',
#   'district': '5',
#   'at_large': False,
#   'geoid': '2205',
#   'missed_votes_pct': 32.35,
#   'votes_with_party_pct': 94.7,
#   'votes_against_party_pct': 5.12},
#  {'id': 'A000370',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000370.json',
#   'first_name': 'Alma',
#   'middle_name': None,
#   'last_name': 'Adams',
#   'suffix': None,
#   'date_of_birth': '1946-05-27',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepAdams',
#   'facebook_account': 'CongresswomanAdams',
#   'youtube_account': None,
#   'govtrack_id': '412607',
#   'cspan_id': '76386',
#   'votesmart_id': '5935',
#   'icpsr_id': '21545',
#   'crp_id': 'N00035451',
#   'google_entity_id': '/m/02b45d',
#   'fec_candidate_id': 'H4NC12100',
#   'url': 'https://adams.house.gov',
#   'rss_url': 'https://adams.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+18',
#   'dw_nominate': -0.466,
#   'ideal_point': None,
#   'seniority': '8',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 26,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:47 -0400',
#   'ocd_id': 'ocd-division/country:us/state:nc/cd:12',
#   'office': '2436 Rayburn House Office Building',
#   'phone': '202-225-1510',
#   'fax': None,
#   'state': 'NC',
#   'district': '12',
#   'at_large': False,
#   'geoid': '3712',
#   'missed_votes_pct': 3.19,
#   'votes_with_party_pct': 99.11,
#   'votes_against_party_pct': 0.76},
#  {'id': 'A000055',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000055.json',
#   'first_name': 'Robert',
#   'middle_name': 'B.',
#   'last_name': 'Aderholt',
#   'suffix': None,
#   'date_of_birth': '1965-07-22',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'Robert_Aderholt',
#   'facebook_account': 'RobertAderholt',
#   'youtube_account': 'RobertAderholt',
#   'govtrack_id': '400004',
#   'cspan_id': '45516',
#   'votesmart_id': '441',
#   'icpsr_id': '29701',
#   'crp_id': 'N00003028',
#   'google_entity_id': '/m/024p03',
#   'fec_candidate_id': 'H6AL04098',
#   'url': 'https://aderholt.house.gov',
#   'rss_url': 'https://aderholt.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+30',
#   'dw_nominate': 0.367,
#   'ideal_point': None,
#   'seniority': '24',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 41,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:36 -0400',
#   'ocd_id': 'ocd-division/country:us/state:al/cd:4',
#   'office': '1203 Longworth House Office Building',
#   'phone': '202-225-4876',
#   'fax': None,
#   'state': 'AL',
#   'district': '4',
#   'at_large': False,
#   'geoid': '0104',
#   'missed_votes_pct': 5.02,
#   'votes_with_party_pct': 93.5,
#   'votes_against_party_pct': 6.37},
#  {'id': 'A000371',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000371.json',
#   'first_name': 'Pete',
#   'middle_name': None,
#   'last_name': 'Aguilar',
#   'suffix': None,
#   'date_of_birth': '1979-06-19',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'reppeteaguilar',
#   'facebook_account': 'reppeteaguilar',
#   'youtube_account': None,
#   'govtrack_id': '412615',
#   'cspan_id': '79994',
#   'votesmart_id': '70114',
#   'icpsr_id': '21506',
#   'crp_id': 'N00033997',
#   'google_entity_id': '/m/0jwv0xf',
#   'fec_candidate_id': 'H2CA31125',
#   'url': 'https://aguilar.house.gov',
#   'rss_url': 'https://aguilar.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+8',
#   'dw_nominate': -0.291,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 8,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:18 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ca/cd:31',
#   'office': '109 Cannon House Office Building',
#   'phone': '202-225-3201',
#   'fax': None,
#   'state': 'CA',
#   'district': '31',
#   'at_large': False,
#   'geoid': '0631',
#   'missed_votes_pct': 0.98,
#   'votes_with_party_pct': 97.39,
#   'votes_against_party_pct': 2.48},
#  {'id': 'A000372',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000372.json',
#   'first_name': 'Rick',
#   'middle_name': None,
#   'last_name': 'Allen',
#   'suffix': None,
#   'date_of_birth': '1951-11-07',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'reprickallen',
#   'facebook_account': 'CongressmanRickAllen',
#   'youtube_account': None,
#   'govtrack_id': '412625',
#   'cspan_id': '62545',
#   'votesmart_id': '136062',
#   'icpsr_id': '21516',
#   'crp_id': 'N00033720',
#   'google_entity_id': '/m/0127y9dk',
#   'fec_candidate_id': 'H2GA12121',
#   'url': 'https://allen.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+9',
#   'dw_nominate': 0.677,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 2,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:02:23 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ga/cd:12',
#   'office': '2400 Rayburn House Office Building',
#   'phone': '202-225-2823',
#   'fax': None,
#   'state': 'GA',
#   'district': '12',
#   'at_large': False,
#   'geoid': '1312',
#   'missed_votes_pct': 0.25,
#   'votes_with_party_pct': 91.95,
#   'votes_against_party_pct': 7.93},
#  {'id': 'A000376',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000376.json',
#   'first_name': 'Colin',
#   'middle_name': None,
#   'last_name': 'Allred',
#   'suffix': None,
#   'date_of_birth': '1983-04-15',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepColinAllred',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412828',
#   'cspan_id': None,
#   'votesmart_id': '177357',
#   'icpsr_id': None,
#   'crp_id': 'N00040989',
#   'google_entity_id': '/m/03d066b',
#   'fec_candidate_id': 'H8TX32098',
#   'url': 'https://allred.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+5',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '2',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 29,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:44 -0400',
#   'ocd_id': 'ocd-division/country:us/state:tx/cd:32',
#   'office': '328 Cannon House Office Building',
#   'phone': '202-225-2231',
#   'fax': None,
#   'state': 'TX',
#   'district': '32',
#   'at_large': False,
#   'geoid': '4832',
#   'missed_votes_pct': 3.55,
#   'votes_with_party_pct': 97.58,
#   'votes_against_party_pct': 2.29},
#  {'id': 'A000367',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000367.json',
#   'first_name': 'Justin',
#   'middle_name': None,
#   'last_name': 'Amash',
#   'suffix': None,
#   'date_of_birth': '1980-04-18',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': '',
#   'twitter_account': None,
#   'facebook_account': 'repjustinamash',
#   'youtube_account': 'repjustinamash',
#   'govtrack_id': '412438',
#   'cspan_id': '1033767',
#   'votesmart_id': '105566',
#   'icpsr_id': '21143',
#   'crp_id': 'N00031938',
#   'google_entity_id': '/m/0c00p_n',
#   'fec_candidate_id': 'H0MI03126',
#   'url': 'https://amash.house.gov',
#   'rss_url': 'https://amash.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': False,
#   'cook_pvi': None,
#   'dw_nominate': 0.654,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 430,
#   'missed_votes': 0,
#   'total_present': 5,
#   'last_updated': '2020-05-28 16:13:34 -0400',
#   'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#   'office': '106 Cannon House Office Building',
#   'phone': '202-225-3831',
#   'fax': None,
#   'state': 'MI',
#   'district': '3',
#   'at_large': False,
#   'geoid': '2603',
#   'missed_votes_pct': 0.0,
#   'votes_with_party_pct': 61.97,
#   'votes_against_party_pct': 37.79},
#  {'id': 'A000367',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000367.json',
#   'first_name': 'Justin',
#   'middle_name': None,
#   'last_name': 'Amash',
#   'suffix': None,
#   'date_of_birth': '1980-04-18',
#   'gender': 'M',
#   'party': 'I',
#   'leadership_role': None,
#   'twitter_account': None,
#   'facebook_account': 'repjustinamash',
#   'youtube_account': 'repjustinamash',
#   'govtrack_id': '412438',
#   'cspan_id': '1033767',
#   'votesmart_id': '105566',
#   'icpsr_id': '21143',
#   'crp_id': 'N00031938',
#   'google_entity_id': '/m/0c00p_n',
#   'fec_candidate_id': '',
#   'url': 'https://amash.house.gov',
#   'rss_url': 'https://amash.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+6',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 386,
#   'missed_votes': 0,
#   'total_present': 6,
#   'last_updated': '2020-06-02 18:02:06 -0400',
#   'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#   'office': None,
#   'phone': None,
#   'fax': None,
#   'state': 'MI',
#   'district': '3',
#   'at_large': False,
#   'geoid': '2603',
#   'missed_votes_pct': 0.0,
#   'votes_with_party_pct': 57.18,
#   'votes_against_party_pct': 42.82},
#  {'id': 'A000369',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000369.json',
#   'first_name': 'Mark',
#   'middle_name': None,
#   'last_name': 'Amodei',
#   'suffix': None,
#   'date_of_birth': '1958-06-12',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'MarkAmodeiNV2',
#   'facebook_account': 'MarkAmodeiNV2',
#   'youtube_account': 'markamodeinv2',
#   'govtrack_id': '412500',
#   'cspan_id': '62817',
#   'votesmart_id': '12537',
#   'icpsr_id': '21196',
#   'crp_id': 'N00031177',
#   'google_entity_id': '/m/03bzdkn',
#   'fec_candidate_id': 'H2NV02395',
#   'url': 'https://amodei.house.gov',
#   'rss_url': 'https://amodei.house.gov/rss/news-releases.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+7',
#   'dw_nominate': 0.381,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 22,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:51 -0400',
#   'ocd_id': 'ocd-division/country:us/state:nv/cd:2',
#   'office': '104 Cannon House Office Building',
#   'phone': '202-225-6155',
#   'fax': None,
#   'state': 'NV',
#   'district': '2',
#   'at_large': False,
#   'geoid': '3202',
#   'missed_votes_pct': 2.7,
#   'votes_with_party_pct': 92.25,
#   'votes_against_party_pct': 7.62},
#  {'id': 'A000377',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000377.json',
#   'first_name': 'Kelly',
#   'middle_name': None,
#   'last_name': 'Armstrong',
#   'suffix': None,
#   'date_of_birth': '1976-10-08',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepArmstrongND',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412794',
#   'cspan_id': None,
#   'votesmart_id': '139338',
#   'icpsr_id': None,
#   'crp_id': 'N00042868',
#   'google_entity_id': '/g/11hcszksh3',
#   'fec_candidate_id': 'H8ND00096',
#   'url': 'https://armstrong.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+16',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '2',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 28,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:45 -0400',
#   'ocd_id': 'ocd-division/country:us/state:nd/cd:1',
#   'office': '1004 Longworth House Office Building',
#   'phone': '202-225-2611',
#   'fax': None,
#   'state': 'ND',
#   'district': 'At-Large',
#   'at_large': True,
#   'geoid': '3800',
#   'missed_votes_pct': 3.43,
#   'votes_with_party_pct': 93.21,
#   'votes_against_party_pct': 6.66},
#  {'id': 'A000375',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000375.json',
#   'first_name': 'Jodey',
#   'middle_name': None,
#   'last_name': 'Arrington',
#   'suffix': None,
#   'date_of_birth': '1972-03-09',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepArrington',
#   'facebook_account': 'JodeyArrington',
#   'youtube_account': None,
#   'govtrack_id': '412726',
#   'cspan_id': '1016482',
#   'votesmart_id': '155685',
#   'icpsr_id': '21700',
#   'crp_id': 'N00038285',
#   'google_entity_id': '/m/0g9_f_1',
#   'fec_candidate_id': 'H6TX19099',
#   'url': 'https://arrington.house.gov',
#   'rss_url': 'https://arrington.house.gov/feed/',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+27',
#   'dw_nominate': 0.625,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 13,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:05 -0400',
#   'ocd_id': 'ocd-division/country:us/state:tx/cd:19',
#   'office': '1029 Longworth House Office Building',
#   'phone': '202-225-4005',
#   'fax': None,
#   'state': 'TX',
#   'district': '19',
#   'at_large': False,
#   'geoid': '4819',
#   'missed_votes_pct': 1.59,
#   'votes_with_party_pct': 90.7,
#   'votes_against_party_pct': 9.17},
#  {'id': 'A000378',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/A000378.json',
#   'first_name': 'Cynthia',
#   'middle_name': None,
#   'last_name': 'Axne',
#   'suffix': None,
#   'date_of_birth': '1965-04-20',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepCindyAxne',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412772',
#   'cspan_id': None,
#   'votesmart_id': '179226',
#   'icpsr_id': None,
#   'crp_id': 'N00041104',
#   'google_entity_id': '/g/11fgktcgcb',
#   'fec_candidate_id': 'H8IA03124',
#   'url': 'https://axne.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+1',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '2',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 17,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:58 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ia/cd:3',
#   'office': '330 Cannon House Office Building',
#   'phone': '202-225-5476',
#   'fax': None,
#   'state': 'IA',
#   'district': '3',
#   'at_large': False,
#   'geoid': '1903',
#   'missed_votes_pct': 2.08,
#   'votes_with_party_pct': 93.73,
#   'votes_against_party_pct': 6.15},
#  {'id': 'B001291',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001291.json',
#   'first_name': 'Brian',
#   'middle_name': None,
#   'last_name': 'Babin',
#   'suffix': None,
#   'date_of_birth': '1948-03-23',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepBrianBabin',
#   'facebook_account': 'RepBrianBabin',
#   'youtube_account': None,
#   'govtrack_id': '412655',
#   'cspan_id': '44883',
#   'votesmart_id': '360',
#   'icpsr_id': '21551',
#   'crp_id': 'N00005736',
#   'google_entity_id': '/m/010qgj35',
#   'fec_candidate_id': 'H6TX02079',
#   'url': 'https://babin.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+26',
#   'dw_nominate': 0.698,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 29,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:44 -0400',
#   'ocd_id': 'ocd-division/country:us/state:tx/cd:36',
#   'office': '2236 Rayburn House Office Building',
#   'phone': '202-225-1555',
#   'fax': None,
#   'state': 'TX',
#   'district': '36',
#   'at_large': False,
#   'geoid': '4836',
#   'missed_votes_pct': 3.55,
#   'votes_with_party_pct': 91.15,
#   'votes_against_party_pct': 8.72},
#  {'id': 'B001298',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001298.json',
#   'first_name': 'Don',
#   'middle_name': None,
#   'last_name': 'Bacon',
#   'suffix': None,
#   'date_of_birth': '1963-08-16',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'repdonbacon',
#   'facebook_account': 'RepDonBacon',
#   'youtube_account': None,
#   'govtrack_id': '412713',
#   'cspan_id': '103442',
#   'votesmart_id': '166299',
#   'icpsr_id': '21701',
#   'crp_id': 'N00037049',
#   'google_entity_id': '/m/01311t71',
#   'fec_candidate_id': 'H6NE02125',
#   'url': 'https://bacon.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+4',
#   'dw_nominate': 0.41,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 1,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:02:14 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ne/cd:2',
#   'office': '1024 Longworth House Office Building',
#   'phone': '202-225-4155',
#   'fax': None,
#   'state': 'NE',
#   'district': '2',
#   'at_large': False,
#   'geoid': '3102',
#   'missed_votes_pct': 0.12,
#   'votes_with_party_pct': 88.0,
#   'votes_against_party_pct': 11.88},
#  {'id': 'B001307',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001307.json',
#   'first_name': 'James',
#   'middle_name': None,
#   'last_name': 'Baird',
#   'suffix': None,
#   'date_of_birth': '1945-06-04',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepJimBaird',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412777',
#   'cspan_id': None,
#   'votesmart_id': '86013',
#   'icpsr_id': None,
#   'crp_id': 'N00041954',
#   'google_entity_id': '/g/11gfd5wndr',
#   'fec_candidate_id': 'H8IN04199',
#   'url': 'https://baird.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+17',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '2',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 7,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:21 -0400',
#   'ocd_id': 'ocd-division/country:us/state:in/cd:4',
#   'office': '532 Cannon House Office Building',
#   'phone': '202-225-5037',
#   'fax': None,
#   'state': 'IN',
#   'district': '4',
#   'at_large': False,
#   'geoid': '1804',
#   'missed_votes_pct': 0.86,
#   'votes_with_party_pct': 95.76,
#   'votes_against_party_pct': 4.11},
#  {'id': 'B001306',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001306.json',
#   'first_name': 'Troy',
#   'middle_name': None,
#   'last_name': 'Balderson',
#   'suffix': None,
#   'date_of_birth': '1962-01-16',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepBalderson',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412747',
#   'cspan_id': None,
#   'votesmart_id': '102781',
#   'icpsr_id': None,
#   'crp_id': 'N00042194',
#   'google_entity_id': '/m/09ry4tm',
#   'fec_candidate_id': 'H8OH12180',
#   'url': 'https://balderson.house.gov',
#   'rss_url': '',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+7',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 1,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:02:56 -0400',
#   'ocd_id': 'ocd-division/country:us/state:oh/cd:12',
#   'office': '1221 Longworth House Office Building',
#   'phone': '202-225-5355',
#   'fax': None,
#   'state': 'OH',
#   'district': '12',
#   'at_large': False,
#   'geoid': '3912',
#   'missed_votes_pct': 0.12,
#   'votes_with_party_pct': 97.03,
#   'votes_against_party_pct': 2.85},
#  {'id': 'B001299',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001299.json',
#   'first_name': 'Jim',
#   'middle_name': None,
#   'last_name': 'Banks',
#   'suffix': None,
#   'date_of_birth': '1979-07-16',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepJimBanks',
#   'facebook_account': 'RepJimBanks',
#   'youtube_account': None,
#   'govtrack_id': '412702',
#   'cspan_id': '89806',
#   'votesmart_id': '116801',
#   'icpsr_id': '21702',
#   'crp_id': 'N00037185',
#   'google_entity_id': '/m/0j621nj',
#   'fec_candidate_id': 'H6IN03229',
#   'url': 'https://banks.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+18',
#   'dw_nominate': 0.633,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 0,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:02:30 -0400',
#   'ocd_id': 'ocd-division/country:us/state:in/cd:3',
#   'office': '1713 Longworth House Office Building',
#   'phone': '202-225-4436',
#   'fax': None,
#   'state': 'IN',
#   'district': '3',
#   'at_large': False,
#   'geoid': '1803',
#   'missed_votes_pct': 0.0,
#   'votes_with_party_pct': 93.33,
#   'votes_against_party_pct': 6.55},
#  {'id': 'B001282',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001282.json',
#   'first_name': 'Andy',
#   'middle_name': None,
#   'last_name': 'Barr',
#   'suffix': None,
#   'date_of_birth': '1973-07-24',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepAndyBarr',
#   'facebook_account': 'RepAndyBarr',
#   'youtube_account': 'RepAndyBarr',
#   'govtrack_id': '412541',
#   'cspan_id': '61848',
#   'votesmart_id': '117290',
#   'icpsr_id': '21333',
#   'crp_id': 'N00031233',
#   'google_entity_id': '/m/0ddc6r6',
#   'fec_candidate_id': 'H0KY06104',
#   'url': 'https://barr.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+9',
#   'dw_nominate': 0.492,
#   'ideal_point': None,
#   'seniority': '8',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 9,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:11 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ky/cd:6',
#   'office': '2430 Rayburn House Office Building',
#   'phone': '202-225-4706',
#   'fax': None,
#   'state': 'KY',
#   'district': '6',
#   'at_large': False,
#   'geoid': '2106',
#   'missed_votes_pct': 1.1,
#   'votes_with_party_pct': 94.63,
#   'votes_against_party_pct': 5.25},
#  {'id': 'B001300',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001300.json',
#   'first_name': 'Nanette',
#   'middle_name': None,
#   'last_name': 'Barragán',
#   'suffix': None,
#   'date_of_birth': '1976-09-15',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepBarragan',
#   'facebook_account': 'CongresswomanBarragan',
#   'youtube_account': None,
#   'govtrack_id': '412687',
#   'cspan_id': '104730',
#   'votesmart_id': '166270',
#   'icpsr_id': '21703',
#   'crp_id': 'N00037019',
#   'google_entity_id': '/g/11bx55ybbz',
#   'fec_candidate_id': 'H6CA44103',
#   'url': 'https://barragan.house.gov',
#   'rss_url': 'https://barragan.house.gov/feed/',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+35',
#   'dw_nominate': -0.51,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 16,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:59 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ca/cd:44',
#   'office': '1030 Longworth House Office Building',
#   'phone': '202-225-8220',
#   'fax': None,
#   'state': 'CA',
#   'district': '44',
#   'at_large': False,
#   'geoid': '0644',
#   'missed_votes_pct': 1.96,
#   'votes_with_party_pct': 98.37,
#   'votes_against_party_pct': 1.5},
#  {'id': 'B001270',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001270.json',
#   'first_name': 'Karen',
#   'middle_name': None,
#   'last_name': 'Bass',
#   'suffix': None,
#   'date_of_birth': '1953-10-03',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepKarenBass',
#   'facebook_account': 'RepKarenBass',
#   'youtube_account': 'RepKarenBass',
#   'govtrack_id': '412404',
#   'cspan_id': '62502',
#   'votesmart_id': '28963',
#   'icpsr_id': '21110',
#   'crp_id': 'N00031877',
#   'google_entity_id': '/m/027g9m6',
#   'fec_candidate_id': 'H0CA33117',
#   'url': 'https://bass.house.gov',
#   'rss_url': 'https://bass.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+37',
#   'dw_nominate': -0.585,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 50,
#   'total_present': 1,
#   'last_updated': '2020-06-02 18:30:33 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ca/cd:37',
#   'office': '2059 Rayburn House Office Building',
#   'phone': '202-225-7084',
#   'fax': None,
#   'state': 'CA',
#   'district': '37',
#   'at_large': False,
#   'geoid': '0637',
#   'missed_votes_pct': 6.13,
#   'votes_with_party_pct': 98.04,
#   'votes_against_party_pct': 1.83},
#  {'id': 'B001281',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001281.json',
#   'first_name': 'Joyce',
#   'middle_name': None,
#   'last_name': 'Beatty',
#   'suffix': None,
#   'date_of_birth': '1950-03-12',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepBeatty',
#   'facebook_account': 'RepJoyceBeatty',
#   'youtube_account': None,
#   'govtrack_id': '412565',
#   'cspan_id': '67294',
#   'votesmart_id': '2427',
#   'icpsr_id': '21352',
#   'crp_id': 'N00033904',
#   'google_entity_id': '/m/03lcwb',
#   'fec_candidate_id': 'H2OH03125',
#   'url': 'https://beatty.house.gov',
#   'rss_url': 'https://beatty.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+19',
#   'dw_nominate': -0.429,
#   'ideal_point': None,
#   'seniority': '8',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 41,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:36 -0400',
#   'ocd_id': 'ocd-division/country:us/state:oh/cd:3',
#   'office': '2303 Rayburn House Office Building',
#   'phone': '202-225-4324',
#   'fax': None,
#   'state': 'OH',
#   'district': '3',
#   'at_large': False,
#   'geoid': '3903',
#   'missed_votes_pct': 5.02,
#   'votes_with_party_pct': 99.22,
#   'votes_against_party_pct': 0.65},
#  {'id': 'B001287',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001287.json',
#   'first_name': 'Ami',
#   'middle_name': None,
#   'last_name': 'Bera',
#   'suffix': None,
#   'date_of_birth': '1965-03-02',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepBera',
#   'facebook_account': 'RepAmiBera',
#   'youtube_account': 'repamibera',
#   'govtrack_id': '412512',
#   'cspan_id': '1033636',
#   'votesmart_id': '120030',
#   'icpsr_id': '21304',
#   'crp_id': 'N00030717',
#   'google_entity_id': '/m/0dgqnts',
#   'fec_candidate_id': 'H0CA03078',
#   'url': 'https://bera.house.gov',
#   'rss_url': 'https://bera.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+3',
#   'dw_nominate': -0.232,
#   'ideal_point': None,
#   'seniority': '8',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 3,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:03:09 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ca/cd:7',
#   'office': '1727 Longworth House Office Building',
#   'phone': '202-225-5716',
#   'fax': None,
#   'state': 'CA',
#   'district': '7',
#   'at_large': False,
#   'geoid': '0607',
#   'missed_votes_pct': 0.37,
#   'votes_with_party_pct': 98.15,
#   'votes_against_party_pct': 1.73},
#  {'id': 'B001301',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001301.json',
#   'first_name': 'Jack',
#   'middle_name': None,
#   'last_name': 'Bergman',
#   'suffix': None,
#   'date_of_birth': '1947-02-02',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepJackBergman',
#   'facebook_account': 'RepJackBergman',
#   'youtube_account': 'RepJackBergman',
#   'govtrack_id': '412709',
#   'cspan_id': '1020529',
#   'votesmart_id': '170172',
#   'icpsr_id': '21704',
#   'crp_id': 'N00039533',
#   'google_entity_id': '/m/05b2l3v',
#   'fec_candidate_id': 'H6MI01226',
#   'url': 'https://bergman.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+9',
#   'dw_nominate': 0.425,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 14,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:05 -0400',
#   'ocd_id': 'ocd-division/country:us/state:mi/cd:1',
#   'office': '414 Cannon House Office Building',
#   'phone': '202-225-4735',
#   'fax': None,
#   'state': 'MI',
#   'district': '1',
#   'at_large': False,
#   'geoid': '2601',
#   'missed_votes_pct': 1.72,
#   'votes_with_party_pct': 92.58,
#   'votes_against_party_pct': 7.3},
#  {'id': 'B001292',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001292.json',
#   'first_name': 'Donald',
#   'middle_name': None,
#   'last_name': 'Beyer',
#   'suffix': None,
#   'date_of_birth': '1950-06-20',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepDonBeyer',
#   'facebook_account': 'RepDonBeyer',
#   'youtube_account': None,
#   'govtrack_id': '412657',
#   'cspan_id': '21141',
#   'votesmart_id': '1707',
#   'icpsr_id': '21554',
#   'crp_id': 'N00036018',
#   'google_entity_id': '/m/053g16',
#   'fec_candidate_id': 'H4VA08224',
#   'url': 'https://beyer.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+6',
#   'dw_nominate': -0.386,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 26,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:48 -0400',
#   'ocd_id': 'ocd-division/country:us/state:va/cd:8',
#   'office': '1119 Longworth House Office Building',
#   'phone': '202-225-4376',
#   'fax': None,
#   'state': 'VA',
#   'district': '8',
#   'at_large': False,
#   'geoid': '5108',
#   'missed_votes_pct': 3.19,
#   'votes_with_party_pct': 98.98,
#   'votes_against_party_pct': 0.89},
#  {'id': 'B001302',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001302.json',
#   'first_name': 'Andy',
#   'middle_name': None,
#   'last_name': 'Biggs',
#   'suffix': None,
#   'date_of_birth': '1958-11-07',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepAndyBiggsAZ',
#   'facebook_account': 'RepAndyBiggs',
#   'youtube_account': None,
#   'govtrack_id': '412683',
#   'cspan_id': '105145',
#   'votesmart_id': '28088',
#   'icpsr_id': '21705',
#   'crp_id': 'N00039293',
#   'google_entity_id': '/m/0_1m23v',
#   'fec_candidate_id': 'H6AZ05083',
#   'url': 'https://biggs.house.gov',
#   'rss_url': 'https://biggs.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+15',
#   'dw_nominate': 0.882,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 19,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:54 -0400',
#   'ocd_id': 'ocd-division/country:us/state:az/cd:5',
#   'office': '1318 Longworth House Office Building',
#   'phone': '202-225-2635',
#   'fax': None,
#   'state': 'AZ',
#   'district': '5',
#   'at_large': False,
#   'geoid': '0405',
#   'missed_votes_pct': 2.33,
#   'votes_with_party_pct': 78.99,
#   'votes_against_party_pct': 20.89},
#  {'id': 'B001257',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001257.json',
#   'first_name': 'Gus',
#   'middle_name': None,
#   'last_name': 'Bilirakis',
#   'suffix': None,
#   'date_of_birth': '1963-02-08',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepGusBilirakis',
#   'facebook_account': 'GusBilirakis',
#   'youtube_account': 'RepGusBilirakis',
#   'govtrack_id': '412250',
#   'cspan_id': '1022873',
#   'votesmart_id': '17318',
#   'icpsr_id': '20758',
#   'crp_id': 'N00027462',
#   'google_entity_id': '/m/0dy3z1',
#   'fec_candidate_id': 'H6FL09070',
#   'url': 'https://bilirakis.house.gov',
#   'rss_url': 'https://bilirakis.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+8',
#   'dw_nominate': 0.404,
#   'ideal_point': None,
#   'seniority': '16',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 30,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:43 -0400',
#   'ocd_id': 'ocd-division/country:us/state:fl/cd:12',
#   'office': '2227 Rayburn House Office Building',
#   'phone': '202-225-5755',
#   'fax': None,
#   'state': 'FL',
#   'district': '12',
#   'at_large': False,
#   'geoid': '1212',
#   'missed_votes_pct': 3.68,
#   'votes_with_party_pct': 92.57,
#   'votes_against_party_pct': 7.3},
#  {'id': 'B001250',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001250.json',
#   'first_name': 'Rob',
#   'middle_name': None,
#   'last_name': 'Bishop',
#   'suffix': None,
#   'date_of_birth': '1951-07-13',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': '',
#   'twitter_account': 'RepRobBishop',
#   'facebook_account': 'RepRobBishop',
#   'youtube_account': 'CongressmanBishop',
#   'govtrack_id': '400029',
#   'cspan_id': '1003621',
#   'votesmart_id': '50544',
#   'icpsr_id': '20357',
#   'crp_id': 'N00025292',
#   'google_entity_id': '/m/02tn41',
#   'fec_candidate_id': 'H2UT01094',
#   'url': 'https://robbishop.house.gov',
#   'rss_url': 'https://robbishop.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+26',
#   'dw_nominate': 0.536,
#   'ideal_point': None,
#   'seniority': '18',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 46,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:36 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ut/cd:1',
#   'office': '123 Cannon House Office Building',
#   'phone': '202-225-0453',
#   'fax': None,
#   'state': 'UT',
#   'district': '1',
#   'at_large': False,
#   'geoid': '4901',
#   'missed_votes_pct': 5.64,
#   'votes_with_party_pct': 91.76,
#   'votes_against_party_pct': 8.1},
#  {'id': 'B001311',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001311.json',
#   'first_name': 'Dan',
#   'middle_name': None,
#   'last_name': 'Bishop',
#   'suffix': None,
#   'date_of_birth': '1964-07-01',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepDanBishop',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412844',
#   'cspan_id': None,
#   'votesmart_id': None,
#   'icpsr_id': None,
#   'crp_id': 'N00044335',
#   'google_entity_id': '/m/013bg9xz',
#   'fec_candidate_id': 'H0NC09187',
#   'url': 'https://danbishop.house.gov/',
#   'rss_url': '',
#   'contact_form': 'https://danbishop.house.gov/contact/email',
#   'in_office': True,
#   'cook_pvi': 'R+8',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '2',
#   'next_election': '2020',
#   'total_votes': 285,
#   'missed_votes': 33,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:41 -0400',
#   'ocd_id': 'ocd-division/country:us/state:nc/cd:9',
#   'office': '132 Cannon House Office Building',
#   'phone': '202-225-1976',
#   'fax': None,
#   'state': 'NC',
#   'district': '9',
#   'at_large': False,
#   'geoid': '3709',
#   'missed_votes_pct': 11.58,
#   'votes_with_party_pct': 93.57,
#   'votes_against_party_pct': 6.43},
#  {'id': 'B000490',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B000490.json',
#   'first_name': 'Sanford',
#   'middle_name': 'D.',
#   'last_name': 'Bishop',
#   'suffix': 'Jr.',
#   'date_of_birth': '1947-02-04',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'SanfordBishop',
#   'facebook_account': 'sanfordbishop',
#   'youtube_account': 'RepSanfordBishop',
#   'govtrack_id': '400030',
#   'cspan_id': '26194',
#   'votesmart_id': '26817',
#   'icpsr_id': '29339',
#   'crp_id': 'N00002674',
#   'google_entity_id': '/m/02554k',
#   'fec_candidate_id': 'H2GA02031',
#   'url': 'https://bishop.house.gov',
#   'rss_url': 'https://bishop.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+6',
#   'dw_nominate': -0.282,
#   'ideal_point': None,
#   'seniority': '28',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 28,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:44 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ga/cd:2',
#   'office': '2407 Rayburn House Office Building',
#   'phone': '202-225-3631',
#   'fax': None,
#   'state': 'GA',
#   'district': '2',
#   'at_large': False,
#   'geoid': '1302',
#   'missed_votes_pct': 3.43,
#   'votes_with_party_pct': 98.73,
#   'votes_against_party_pct': 1.15},
#  {'id': 'B000574',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B000574.json',
#   'first_name': 'Earl',
#   'middle_name': None,
#   'last_name': 'Blumenauer',
#   'suffix': None,
#   'date_of_birth': '1948-08-16',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'BlumenauerMedia',
#   'facebook_account': None,
#   'youtube_account': 'RepBlumenauer',
#   'govtrack_id': '400033',
#   'cspan_id': '43809',
#   'votesmart_id': '367',
#   'icpsr_id': '29588',
#   'crp_id': 'N00007727',
#   'google_entity_id': '/m/033tw8',
#   'fec_candidate_id': 'H6OR03064',
#   'url': 'https://blumenauer.house.gov',
#   'rss_url': 'https://blumenauer.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+24',
#   'dw_nominate': -0.427,
#   'ideal_point': None,
#   'seniority': '26',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 10,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:10 -0400',
#   'ocd_id': 'ocd-division/country:us/state:or/cd:3',
#   'office': '1111 Longworth House Office Building',
#   'phone': '202-225-4811',
#   'fax': None,
#   'state': 'OR',
#   'district': '3',
#   'at_large': False,
#   'geoid': '4103',
#   'missed_votes_pct': 1.23,
#   'votes_with_party_pct': 97.51,
#   'votes_against_party_pct': 2.36},
#  {'id': 'B001303',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001303.json',
#   'first_name': 'Lisa',
#   'middle_name': None,
#   'last_name': 'Blunt Rochester',
#   'suffix': None,
#   'date_of_birth': '1962-02-10',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepLBR',
#   'facebook_account': 'Rep.BluntRochester',
#   'youtube_account': None,
#   'govtrack_id': '412689',
#   'cspan_id': '104772',
#   'votesmart_id': '173249',
#   'icpsr_id': '21706',
#   'crp_id': 'N00038414',
#   'google_entity_id': '/g/11c328y56v',
#   'fec_candidate_id': 'H6DE00206',
#   'url': 'https://bluntrochester.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+6',
#   'dw_nominate': -0.329,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 5,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:03:36 -0400',
#   'ocd_id': 'ocd-division/country:us/state:de/cd:1',
#   'office': '1519 Longworth House Office Building',
#   'phone': '202-225-4165',
#   'fax': None,
#   'state': 'DE',
#   'district': 'At-Large',
#   'at_large': True,
#   'geoid': '1000',
#   'missed_votes_pct': 0.61,
#   'votes_with_party_pct': 99.38,
#   'votes_against_party_pct': 0.49},
#  {'id': 'B001278',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001278.json',
#   'first_name': 'Suzanne',
#   'middle_name': None,
#   'last_name': 'Bonamici',
#   'suffix': None,
#   'date_of_birth': '1954-10-14',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepBonamici',
#   'facebook_account': 'congresswomanbonamici',
#   'youtube_account': 'RepSuzanneBonamici',
#   'govtrack_id': '412501',
#   'cspan_id': '63966',
#   'votesmart_id': '59641',
#   'icpsr_id': '21198',
#   'crp_id': 'N00033474',
#   'google_entity_id': '/m/02q453x',
#   'fec_candidate_id': 'H2OR01133',
#   'url': 'https://bonamici.house.gov',
#   'rss_url': 'https://bonamici.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+9',
#   'dw_nominate': -0.393,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 4,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:03:17 -0400',
#   'ocd_id': 'ocd-division/country:us/state:or/cd:1',
#   'office': '2231 Rayburn House Office Building',
#   'phone': '202-225-0855',
#   'fax': None,
#   'state': 'OR',
#   'district': '1',
#   'at_large': False,
#   'geoid': '4101',
#   'missed_votes_pct': 0.49,
#   'votes_with_party_pct': 98.52,
#   'votes_against_party_pct': 1.36},
#  {'id': 'B001295',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001295.json',
#   'first_name': 'Mike',
#   'middle_name': None,
#   'last_name': 'Bost',
#   'suffix': None,
#   'date_of_birth': '1960-12-30',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepBost',
#   'facebook_account': 'RepBost',
#   'youtube_account': None,
#   'govtrack_id': '412629',
#   'cspan_id': '76176',
#   'votesmart_id': '6302',
#   'icpsr_id': '21519',
#   'crp_id': 'N00035420',
#   'google_entity_id': '/m/0kry42',
#   'fec_candidate_id': 'H4IL12060',
#   'url': 'https://bost.house.gov',
#   'rss_url': 'https://bost.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+5',
#   'dw_nominate': 0.27,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 92,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:27 -0400',
#   'ocd_id': 'ocd-division/country:us/state:il/cd:12',
#   'office': '1440 Longworth House Office Building',
#   'phone': '202-225-5661',
#   'fax': None,
#   'state': 'IL',
#   'district': '12',
#   'at_large': False,
#   'geoid': '1712',
#   'missed_votes_pct': 11.27,
#   'votes_with_party_pct': 92.2,
#   'votes_against_party_pct': 7.66},
#  {'id': 'B001296',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001296.json',
#   'first_name': 'Brendan',
#   'middle_name': None,
#   'last_name': 'Boyle',
#   'suffix': None,
#   'date_of_birth': '1977-02-06',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'CongBoyle',
#   'facebook_account': 'CongressmanBoyle',
#   'youtube_account': None,
#   'govtrack_id': '412652',
#   'cspan_id': '76428',
#   'votesmart_id': '47357',
#   'icpsr_id': '21548',
#   'crp_id': 'N00035307',
#   'google_entity_id': '/m/04f4fjk',
#   'fec_candidate_id': 'H4PA13199',
#   'url': 'https://boyle.house.gov',
#   'rss_url': 'https://boyle.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+25',
#   'dw_nominate': -0.396,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 14,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:03 -0400',
#   'ocd_id': 'ocd-division/country:us/state:pa/cd:2',
#   'office': '1133 Longworth House Office Building',
#   'phone': '202-225-6111',
#   'fax': None,
#   'state': 'PA',
#   'district': '2',
#   'at_large': False,
#   'geoid': '4202',
#   'missed_votes_pct': 1.72,
#   'votes_with_party_pct': 98.63,
#   'votes_against_party_pct': 1.25},
#  {'id': 'B000755',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B000755.json',
#   'first_name': 'Kevin',
#   'middle_name': None,
#   'last_name': 'Brady',
#   'suffix': None,
#   'date_of_birth': '1955-04-11',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepKevinBrady',
#   'facebook_account': 'kevinbrady',
#   'youtube_account': 'KBrady8',
#   'govtrack_id': '400046',
#   'cspan_id': '45749',
#   'votesmart_id': '361',
#   'icpsr_id': '29760',
#   'crp_id': 'N00005883',
#   'google_entity_id': '/m/03tq00',
#   'fec_candidate_id': 'H6TX08100',
#   'url': 'https://kevinbrady.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+28',
#   'dw_nominate': 0.524,
#   'ideal_point': None,
#   'seniority': '24',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 52,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:33 -0400',
#   'ocd_id': 'ocd-division/country:us/state:tx/cd:8',
#   'office': '1011 Longworth House Office Building',
#   'phone': '202-225-4901',
#   'fax': None,
#   'state': 'TX',
#   'district': '8',
#   'at_large': False,
#   'geoid': '4808',
#   'missed_votes_pct': 6.37,
#   'votes_with_party_pct': 93.79,
#   'votes_against_party_pct': 6.08},
#  {'id': 'B001308',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001308.json',
#   'first_name': 'Anthony',
#   'middle_name': None,
#   'last_name': 'Brindisi',
#   'suffix': None,
#   'date_of_birth': '1978-11-22',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepBrindisi',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412806',
#   'cspan_id': None,
#   'votesmart_id': '135258',
#   'icpsr_id': None,
#   'crp_id': 'N00041385',
#   'google_entity_id': '/m/0hhqfyc',
#   'fec_candidate_id': 'H8NY22151',
#   'url': 'https://brindisi.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+6',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '2',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 3,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:02:16 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ny/cd:22',
#   'office': '329 Cannon House Office Building',
#   'phone': '202-225-3665',
#   'fax': None,
#   'state': 'NY',
#   'district': '22',
#   'at_large': False,
#   'geoid': '3622',
#   'missed_votes_pct': 0.37,
#   'votes_with_party_pct': 89.03,
#   'votes_against_party_pct': 10.85},
#  {'id': 'B001274',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/B001274.json',
#   'first_name': 'Mo',
#   'middle_name': None,
#   'last_name': 'Brooks',
#   'suffix': None,
#   'date_of_birth': '1954-04-29',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepMoBrooks',
#   'facebook_account': 'RepMoBrooks',
#   'youtube_account': 'RepMoBrooks',
#   'govtrack_id': '412395',
#   'cspan_id': '94888',
#   'votesmart_id': '121610',
#   'icpsr_id': '21193',
#   'crp_id': 'N00030910',
#   'google_entity_id': '/m/0c3xdjf',
#   'fec_candidate_id': 'H0AL05163',
#   'url': 'https://brooks.house.gov',
#   'rss_url': 'https://brooks.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+18',
#   'dw_nominate': 0.647,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 11,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:09 -0400',
#   'ocd_id': 'ocd-division/country:us/state:al/cd:5',
#   'office': '2246 Rayburn House Office Building',
#   'phone': '202-225-4801',
#   'fax': None,
#   'state': 'AL',
#   'district': '5',
#   'at_large': False,
# ...
#   'office': '1217 Longworth House Office Building',
#   'phone': '202-225-5136',
#   'fax': None,
#   'state': 'VA',
#   'district': '10',
#   'at_large': False,
#   'geoid': '5110',
#   'missed_votes_pct': 0.37,
#   'votes_with_party_pct': 97.78,
#   'votes_against_party_pct': 2.1},
#  {'id': 'W000826',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000826.json',
#   'first_name': 'Susan',
#   'middle_name': None,
#   'last_name': 'Wild',
#   'suffix': None,
#   'date_of_birth': '1957-06-07',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepSusanWild',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412751',
#   'cspan_id': None,
#   'votesmart_id': '178895',
#   'icpsr_id': None,
#   'crp_id': 'N00041997',
#   'google_entity_id': '/g/11gtg86jn6',
#   'fec_candidate_id': 'H8PA15229',
#   'url': 'https://wild.house.gov',
#   'rss_url': '',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+1',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '4',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 9,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:14 -0400',
#   'ocd_id': 'ocd-division/country:us/state:pa/cd:7',
#   'office': '1607 Longworth House Office Building',
#   'phone': '202-225-6411',
#   'fax': None,
#   'state': 'PA',
#   'district': '7',
#   'at_large': False,
#   'geoid': '4207',
#   'missed_votes_pct': 1.1,
#   'votes_with_party_pct': 95.9,
#   'votes_against_party_pct': 3.98},
#  {'id': 'W000816',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000816.json',
#   'first_name': 'Roger',
#   'middle_name': None,
#   'last_name': 'Williams',
#   'suffix': None,
#   'date_of_birth': '1949-09-13',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepRWilliams',
#   'facebook_account': 'RepRogerWilliams',
#   'youtube_account': None,
#   'govtrack_id': '412578',
#   'cspan_id': '623742',
#   'votesmart_id': '50112',
#   'icpsr_id': '21364',
#   'crp_id': 'N00030602',
#   'google_entity_id': '/m/08rszb',
#   'fec_candidate_id': 'H2TX33040',
#   'url': 'https://williams.house.gov',
#   'rss_url': 'https://williams.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+11',
#   'dw_nominate': 0.587,
#   'ideal_point': None,
#   'seniority': '8',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 24,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:50 -0400',
#   'ocd_id': 'ocd-division/country:us/state:tx/cd:25',
#   'office': '1708 Longworth House Office Building',
#   'phone': '202-225-9896',
#   'fax': None,
#   'state': 'TX',
#   'district': '25',
#   'at_large': False,
#   'geoid': '4825',
#   'missed_votes_pct': 2.94,
#   'votes_with_party_pct': 95.29,
#   'votes_against_party_pct': 4.58},
#  {'id': 'W000795',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000795.json',
#   'first_name': 'Joe',
#   'middle_name': None,
#   'last_name': 'Wilson',
#   'suffix': None,
#   'date_of_birth': '1947-07-31',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepJoeWilson',
#   'facebook_account': 'JoeWilson',
#   'youtube_account': 'RepJoeWilson',
#   'govtrack_id': '400433',
#   'cspan_id': '1002567',
#   'votesmart_id': '3985',
#   'icpsr_id': '20138',
#   'crp_id': 'N00024809',
#   'google_entity_id': '/m/03tll0',
#   'fec_candidate_id': 'H2SC02059',
#   'url': 'https://joewilson.house.gov',
#   'rss_url': 'https://joewilson.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+12',
#   'dw_nominate': 0.538,
#   'ideal_point': None,
#   'seniority': '20',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 27,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:46 -0400',
#   'ocd_id': 'ocd-division/country:us/state:sc/cd:2',
#   'office': '1436 Longworth House Office Building',
#   'phone': '202-225-2452',
#   'fax': None,
#   'state': 'SC',
#   'district': '2',
#   'at_large': False,
#   'geoid': '4502',
#   'missed_votes_pct': 3.31,
#   'votes_with_party_pct': 94.63,
#   'votes_against_party_pct': 5.24},
#  {'id': 'W000808',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000808.json',
#   'first_name': 'Frederica',
#   'middle_name': None,
#   'last_name': 'Wilson',
#   'suffix': None,
#   'date_of_birth': '1942-11-05',
#   'gender': 'F',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepWilson',
#   'facebook_account': 'RepWilson',
#   'youtube_account': 'repfredericawilson',
#   'govtrack_id': '412412',
#   'cspan_id': '87016',
#   'votesmart_id': '17319',
#   'icpsr_id': '21118',
#   'crp_id': 'N00030650',
#   'google_entity_id': '/m/03cg3tv',
#   'fec_candidate_id': 'H0FL17068',
#   'url': 'https://wilson.house.gov',
#   'rss_url': 'https://wilson.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+34',
#   'dw_nominate': -0.476,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 118,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:25 -0400',
#   'ocd_id': 'ocd-division/country:us/state:fl/cd:24',
#   'office': '2445 Rayburn House Office Building',
#   'phone': '202-225-4506',
#   'fax': None,
#   'state': 'FL',
#   'district': '24',
#   'at_large': False,
#   'geoid': '1224',
#   'missed_votes_pct': 14.46,
#   'votes_with_party_pct': 99.0,
#   'votes_against_party_pct': 0.86},
#  {'id': 'W000804',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000804.json',
#   'first_name': 'Robert',
#   'middle_name': 'J.',
#   'last_name': 'Wittman',
#   'suffix': None,
#   'date_of_birth': '1959-02-03',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RobWittman',
#   'facebook_account': 'RepRobWittman',
#   'youtube_account': 'RobWittman',
#   'govtrack_id': '412255',
#   'cspan_id': '1028089',
#   'votesmart_id': '58133',
#   'icpsr_id': '20756',
#   'crp_id': 'N00029459',
#   'google_entity_id': '/m/03cx7ld',
#   'fec_candidate_id': 'H8VA01147',
#   'url': 'https://wittman.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+15',
#   'dw_nominate': 0.444,
#   'ideal_point': None,
#   'seniority': '14',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 7,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:20 -0400',
#   'ocd_id': 'ocd-division/country:us/state:va/cd:1',
#   'office': '2055 Rayburn House Office Building',
#   'phone': '202-225-4261',
#   'fax': None,
#   'state': 'VA',
#   'district': '1',
#   'at_large': False,
#   'geoid': '5101',
#   'missed_votes_pct': 0.86,
#   'votes_with_party_pct': 95.64,
#   'votes_against_party_pct': 4.23},
#  {'id': 'W000809',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000809.json',
#   'first_name': 'Steve',
#   'middle_name': None,
#   'last_name': 'Womack',
#   'suffix': None,
#   'date_of_birth': '1957-02-18',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'Rep_SteveWomack',
#   'facebook_account': 'RepSteveWomack',
#   'youtube_account': 'CongressmanWomack',
#   'govtrack_id': '412402',
#   'cspan_id': '1033625',
#   'votesmart_id': '71815',
#   'icpsr_id': '21108',
#   'crp_id': 'N00031857',
#   'google_entity_id': '/m/0cmcvkz',
#   'fec_candidate_id': 'H0AR03055',
#   'url': 'https://womack.house.gov',
#   'rss_url': 'https://womack.house.gov/news/rss.aspx',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+19',
#   'dw_nominate': 0.354,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 0,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:02:44 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ar/cd:3',
#   'office': '2412 Rayburn House Office Building',
#   'phone': '202-225-4301',
#   'fax': None,
#   'state': 'AR',
#   'district': '3',
#   'at_large': False,
#   'geoid': '0503',
#   'missed_votes_pct': 0.0,
#   'votes_with_party_pct': 95.43,
#   'votes_against_party_pct': 4.45},
#  {'id': 'W000810',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000810.json',
#   'first_name': 'Rob',
#   'middle_name': None,
#   'last_name': 'Woodall',
#   'suffix': None,
#   'date_of_birth': '1970-02-11',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': '',
#   'twitter_account': 'RepRobWoodall',
#   'facebook_account': 'RepRobWoodall',
#   'youtube_account': 'RobWoodallGA07',
#   'govtrack_id': '412416',
#   'cspan_id': '623342',
#   'votesmart_id': '122251',
#   'icpsr_id': '21122',
#   'crp_id': 'N00032416',
#   'google_entity_id': '/m/0cz8ryh',
#   'fec_candidate_id': 'H0GA07133',
#   'url': 'https://woodall.house.gov',
#   'rss_url': 'https://woodall.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+9',
#   'dw_nominate': 0.598,
#   'ideal_point': None,
#   'seniority': '10',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 12,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:08 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ga/cd:7',
#   'office': '1724 Longworth House Office Building',
#   'phone': '202-225-4272',
#   'fax': None,
#   'state': 'GA',
#   'district': '7',
#   'at_large': False,
#   'geoid': '1307',
#   'missed_votes_pct': 1.47,
#   'votes_with_party_pct': 94.11,
#   'votes_against_party_pct': 5.76},
#  {'id': 'W000827',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/W000827.json',
#   'first_name': 'Ron',
#   'middle_name': None,
#   'last_name': 'Wright',
#   'suffix': None,
#   'date_of_birth': '1953-04-08',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepRonWright',
#   'facebook_account': None,
#   'youtube_account': None,
#   'govtrack_id': '412823',
#   'cspan_id': None,
#   'votesmart_id': None,
#   'icpsr_id': None,
#   'crp_id': 'N00042240',
#   'google_entity_id': '/g/11fgkl82tl',
#   'fec_candidate_id': 'H8TX06233',
#   'url': 'https://wright.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+9',
#   'dw_nominate': None,
#   'ideal_point': None,
#   'seniority': '2',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 162,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:25 -0400',
#   'ocd_id': 'ocd-division/country:us/state:tx/cd:6',
#   'office': '428 Cannon House Office Building',
#   'phone': '202-225-2002',
#   'fax': None,
#   'state': 'TX',
#   'district': '6',
#   'at_large': False,
#   'geoid': '4806',
#   'missed_votes_pct': 19.85,
#   'votes_with_party_pct': 92.91,
#   'votes_against_party_pct': 6.93},
#  {'id': 'Y000062',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/Y000062.json',
#   'first_name': 'John',
#   'middle_name': None,
#   'last_name': 'Yarmuth',
#   'suffix': None,
#   'date_of_birth': '1947-11-04',
#   'gender': 'M',
#   'party': 'D',
#   'leadership_role': None,
#   'twitter_account': 'RepJohnYarmuth',
#   'facebook_account': '214258646163',
#   'youtube_account': 'RepJohnYarmuth',
#   'govtrack_id': '412211',
#   'cspan_id': '1021662',
#   'votesmart_id': '58579',
#   'icpsr_id': '20723',
#   'crp_id': 'N00028073',
#   'google_entity_id': '/m/0bb00g',
#   'fec_candidate_id': 'H6KY03124',
#   'url': 'https://yarmuth.house.gov',
#   'rss_url': None,
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'D+6',
#   'dw_nominate': -0.378,
#   'ideal_point': None,
#   'seniority': '14',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 17,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:57 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ky/cd:3',
#   'office': '402 Cannon House Office Building',
#   'phone': '202-225-5401',
#   'fax': None,
#   'state': 'KY',
#   'district': '3',
#   'at_large': False,
#   'geoid': '2103',
#   'missed_votes_pct': 2.08,
#   'votes_with_party_pct': 98.87,
#   'votes_against_party_pct': 1.0},
#  {'id': 'Y000065',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/Y000065.json',
#   'first_name': 'Ted',
#   'middle_name': None,
#   'last_name': 'Yoho',
#   'suffix': None,
#   'date_of_birth': '1955-04-13',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': '',
#   'twitter_account': 'RepTedYoho',
#   'facebook_account': 'CongressmanTedYoho',
#   'youtube_account': 'RepTedYoho',
#   'govtrack_id': '412525',
#   'cspan_id': '63943',
#   'votesmart_id': '137622',
#   'icpsr_id': '21317',
#   'crp_id': 'N00033220',
#   'google_entity_id': '/m/0l8lwvh',
#   'fec_candidate_id': 'H2FL06109',
#   'url': 'https://yoho.house.gov',
#   'rss_url': 'https://yoho.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+9',
#   'dw_nominate': 0.704,
#   'ideal_point': None,
#   'seniority': '8',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 69,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:30 -0400',
#   'ocd_id': 'ocd-division/country:us/state:fl/cd:3',
#   'office': '1730 Longworth House Office Building',
#   'phone': '202-225-5744',
#   'fax': None,
#   'state': 'FL',
#   'district': '3',
#   'at_large': False,
#   'geoid': '1203',
#   'missed_votes_pct': 8.46,
#   'votes_with_party_pct': 87.06,
#   'votes_against_party_pct': 12.8},
#  {'id': 'Y000033',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/Y000033.json',
#   'first_name': 'Don',
#   'middle_name': None,
#   'last_name': 'Young',
#   'suffix': None,
#   'date_of_birth': '1933-06-09',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepDonYoung',
#   'facebook_account': 'RepDonYoung',
#   'youtube_account': 'RepDonYoung',
#   'govtrack_id': '400440',
#   'cspan_id': '1897',
#   'votesmart_id': '26717',
#   'icpsr_id': '14066',
#   'crp_id': 'N00007999',
#   'google_entity_id': '/m/024p1k',
#   'fec_candidate_id': 'H6AK00045',
#   'url': 'https://donyoung.house.gov',
#   'rss_url': 'https://donyoung.house.gov/news/rss.aspx',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+9',
#   'dw_nominate': 0.284,
#   'ideal_point': None,
#   'seniority': '48',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 36,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:30:39 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ak/cd:1',
#   'office': '2314 Rayburn House Office Building',
#   'phone': '202-225-5765',
#   'fax': None,
#   'state': 'AK',
#   'district': 'At-Large',
#   'at_large': True,
#   'geoid': '0200',
#   'missed_votes_pct': 4.41,
#   'votes_with_party_pct': 87.98,
#   'votes_against_party_pct': 11.89},
#  {'id': 'Z000017',
#   'title': 'Representative',
#   'short_title': 'Rep.',
#   'api_uri': 'https://api.propublica.org/congress/v1/members/Z000017.json',
#   'first_name': 'Lee',
#   'middle_name': None,
#   'last_name': 'Zeldin',
#   'suffix': None,
#   'date_of_birth': '1980-01-30',
#   'gender': 'M',
#   'party': 'R',
#   'leadership_role': None,
#   'twitter_account': 'RepLeeZeldin',
#   'facebook_account': 'RepLeeZeldin',
#   'youtube_account': None,
#   'govtrack_id': '412646',
#   'cspan_id': '61616',
#   'votesmart_id': '110252',
#   'icpsr_id': '21539',
#   'crp_id': 'N00029404',
#   'google_entity_id': '/m/03h4jcq',
#   'fec_candidate_id': 'H8NY01148',
#   'url': 'https://zeldin.house.gov',
#   'rss_url': 'https://zeldin.house.gov/rss.xml',
#   'contact_form': None,
#   'in_office': True,
#   'cook_pvi': 'R+5',
#   'dw_nominate': 0.387,
#   'ideal_point': None,
#   'seniority': '6',
#   'next_election': '2020',
#   'total_votes': 816,
#   'missed_votes': 8,
#   'total_present': 0,
#   'last_updated': '2020-06-02 18:31:17 -0400',
#   'ocd_id': 'ocd-division/country:us/state:ny/cd:1',
#   'office': '2441 Rayburn House Office Building',
#   'phone': '202-225-3826',
#   'fax': None,
#   'state': 'NY',
#   'district': '1',
#   'at_large': False,
#   'geoid': '3601',
#   'missed_votes_pct': 0.98,
#   'votes_with_party_pct': 89.26,
#   'votes_against_party_pct': 10.61}]

# %%
len(congress_members)
# Out:
# 448

# %%
# Drops collection if available to remove duplicates
db.members.drop()
# Creates a collection in the database and inserts two documents
db.members.insert_many(congress_members)
